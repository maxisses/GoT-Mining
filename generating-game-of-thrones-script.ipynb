# %% [markdown]
# # --> This code is originally from albenft <--
#
# https://www.kaggle.com/albenft/generating-game-of-thrones-script
#
# # I only made some minor adaptions e.g. trying to extract scene cuts.

# %% [markdown]
# # Introduction
# On this kernel, I will explain step by step I done in generating Script for Game of Thrones series.
#
# The site I used for scrapping is genius.com. This site contains a whole scripts of Game of Thrones series for all episodes.

# %% [markdown]
# ## Scrapping Episodes Urls
# ### Loading the Required Packages
# Packages used for scrapping the episodes list are:
# * requests
# * BeautifulSoup

# %%
import requests # Used for doing the http request
from bs4 import BeautifulSoup # Used for assisting the HTML read

# %% [markdown]
# ### Urls Scrapping
# Example URL for an album in genius.com is as following (https://genius.com/albums/Game-of-thrones/Season-1-scripts ). In our case, album means season of a series. Each album contains a full list of URLs used to access the lyrics of all the songs in the album. Then again, songs can be interpreted as episodes of a series in a single season (album).
#
# From the example above we can see that the season URLs are structured following this pattern below:
# > 'https://genius.com/albums/Game-of-thrones/Season-' + [Season Number] + '-scripts'
#
# We know that Game of Thrones has already finished with 8 seasons in total. Therefore we will have 8 different URLs for each season.
#
# In order to capture the URLs for each season, we can make a simple list comprehension to generate the URL for each season which follows the pattern we've discovered before.

# %%
season_urls = ['https://genius.com/albums/Game-of-thrones/Season-' + str(season_number) + '-scripts' for season_number in range(1,9)]

# %% [markdown]
# Let's take a look at our season URLs.

# %%
for season_url in season_urls:
    print(season_url)
# Out:
# https://genius.com/albums/Game-of-thrones/Season-1-scripts
# https://genius.com/albums/Game-of-thrones/Season-2-scripts
# https://genius.com/albums/Game-of-thrones/Season-3-scripts
# https://genius.com/albums/Game-of-thrones/Season-4-scripts
# https://genius.com/albums/Game-of-thrones/Season-5-scripts
# https://genius.com/albums/Game-of-thrones/Season-6-scripts
# https://genius.com/albums/Game-of-thrones/Season-7-scripts
# https://genius.com/albums/Game-of-thrones/Season-8-scripts

# %% [markdown]
# Now that we already have the URLs for each season, we can take a look at the inner HTML from one of those URLs.
# We can do HTTP request using requests package that we imported, and then save the HTML result as a BeautifulSoup object.
#
# BeautifulSoup will wrap the result of a requests from raw string/text format to a structured data type known as BeautifulSoup object.

# %%
r = requests.get(season_urls[0])
html_doc = r.text
soup = BeautifulSoup(html_doc)

# only view snippet because the result is too large
str(soup)[:1000]
# Out:
# '\n<!DOCTYPE html>\n\n<html class="snarly bagon_song_page--enabled song_stories_public_launch--enabled react_forums--disabled react_song_page--disabled" lang="en" xml:lang="en" xmlns="http://www.w3.org/1999/xhtml" xmlns:fb="http://www.facebook.com/2008/fbml">\n<head>\n<base href="//genius.com/" target="_top"/>\n<script type="text/javascript">\n//<![CDATA[\n\n  var _sf_startpt=(new Date()).getTime();\n  if (window.performance && performance.mark) {\n    window.performance.mark(\'parse_start\');\n  }\n\n//]]>\n</script>\n<title>Game of Thrones - Season 1 Scripts Lyrics and Tracklist | Genius</title>\n<meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>\n<meta content="width=device-width,initial-scale=1" name="viewport"/>\n<meta content="app-id=709482991" name="apple-itunes-app"/>\n<link href="https://assets.genius.com/images/apple-touch-icon.png?1581523915" rel="apple-touch-icon"/>\n<link href="https://assets.genius.com/images/apple-touch-icon.png?1581523915" rel="apple-touch-icon"/>\n<!-- Mobile'

# %% [markdown]
# If we look at the HTML text comprehensively, we can see that the URLs for each episode in a season are wrapped in an `a` tag with class name of `u-display_block`.
#
# In BeautifulSoup object, we can easily access each of html tag with specific attribute using a method called `.find_all()`.

# %%
url_containers = soup.find_all('a', class_='u-display_block')
# take a look at one of the items
url_containers[2]
# Out:
# <a class="u-display_block" href="https://genius.com/Game-of-thrones-lord-snow-annotated">
# <h3 class="chart_row-content-title">
#               Lord Snow
#               <span class="chart_row-content-title-subtitle">Lyrics</span>
# </h3>
# </a>

# %% [markdown]
# From one of the html `a` tag above we know that the URL for each episode is stored in the attribute `href`. Tag in `BeautifulSoup` is kind of similar to `dictionary` in python in term of (`attribute`, `value of attribute`) from a tag can be treated as (`key`, `value`) from a dictionary. Therefore we can get the URL of the episode by simply accessing the `href` attribute of an `a` tag using the same method as accessing value of a python dictionary.

# %%
urls = [url_container['href'] for url_container in url_containers]

# Take a look at the URLs inside
for url in urls:
    print(url)
# Out:
# https://genius.com/Game-of-thrones-winter-is-coming-annotated
# https://genius.com/Game-of-thrones-the-kingsroad-annotated
# https://genius.com/Game-of-thrones-lord-snow-annotated
# https://genius.com/Game-of-thrones-cripples-bastards-and-broken-things-annotated
# https://genius.com/Game-of-thrones-the-wolf-and-the-lion-annotated
# https://genius.com/Game-of-thrones-a-golden-crown-annotated
# https://genius.com/Game-of-thrones-you-win-or-you-die-annotated
# https://genius.com/Game-of-thrones-the-pointy-end-annotated
# https://genius.com/Game-of-thrones-baelor-annotated
# https://genius.com/Game-of-thrones-fire-and-blood-annotated

# %% [markdown]
# Now we know how to get the URL for each episode in a season of Game of Thrones. Next we need to do is extracting the URLs for all episodes from all seasons. We can do this by making simple loop of the season URLs and wrap all of what we have done before in order to get the episode URLs inside the loop.

# %%
urls = []
for season_url in season_urls:
    
    r = requests.get(season_url)
    html_doc = r.text
    soup = BeautifulSoup(html_doc)
    
    url_containers = soup.find_all('a', class_='u-display_block')
    
    for url_container in url_containers:
        urls.append(url_container['href'])

# %%
# show number of episodes
len(urls)
# Out:
# 75

# %% [markdown]
# There are some anomalies in the URLs that we got. We know that Game of Thrones only consists of 73 episodes in total, but based on our scrap we captured more than 73 episodes.

# %%
for url in urls:
    print(url)
# Out:
# https://genius.com/Game-of-thrones-winter-is-coming-annotated
# https://genius.com/Game-of-thrones-the-kingsroad-annotated
# https://genius.com/Game-of-thrones-lord-snow-annotated
# https://genius.com/Game-of-thrones-cripples-bastards-and-broken-things-annotated
# https://genius.com/Game-of-thrones-the-wolf-and-the-lion-annotated
# https://genius.com/Game-of-thrones-a-golden-crown-annotated
# https://genius.com/Game-of-thrones-you-win-or-you-die-annotated
# https://genius.com/Game-of-thrones-the-pointy-end-annotated
# https://genius.com/Game-of-thrones-baelor-annotated
# https://genius.com/Game-of-thrones-fire-and-blood-annotated
# https://genius.com/Game-of-thrones-the-north-remembers-annotated
# https://genius.com/Game-of-thrones-the-night-lands-annotated
# https://genius.com/Game-of-thrones-what-is-dead-may-never-die-annotated
# https://genius.com/Game-of-thrones-garden-of-bones-annotated
# https://genius.com/Game-of-thrones-the-ghost-of-harrenhal-annotated
# https://genius.com/Game-of-thrones-the-old-gods-and-the-new-annotated
# https://genius.com/Game-of-thrones-a-man-without-honor-annotated
# https://genius.com/Game-of-thrones-the-prince-of-winterfell-annotated
# https://genius.com/Game-of-thrones-blackwater-annotated
# https://genius.com/Game-of-thrones-valar-morghulis-annotated
# https://genius.com/Game-of-thrones-valar-dohaeris-annotated
# https://genius.com/Game-of-thrones-dark-wings-dark-words-annotated
# https://genius.com/Game-of-thrones-walk-of-punishment-annotated
# https://genius.com/Game-of-thrones-and-now-his-watch-is-ended-annotated
# https://genius.com/Game-of-thrones-kissed-by-fire-annotated
# https://genius.com/Game-of-thrones-the-climb-annotated
# https://genius.com/Game-of-thrones-the-bear-and-the-maiden-fair-annotated
# https://genius.com/Game-of-thrones-second-sons-annotated
# https://genius.com/Game-of-thrones-the-rains-of-castamere-annotated
# https://genius.com/Game-of-thrones-mhysa-annotated
# https://genius.com/Game-of-thrones-two-swords-annotated
# https://genius.com/Game-of-thrones-the-lion-and-the-rose-annotated
# https://genius.com/Game-of-thrones-breaker-of-chains-annotated
# https://genius.com/Game-of-thrones-oathkeeper-annotated
# https://genius.com/Game-of-thrones-first-of-his-name-annotated
# https://genius.com/Game-of-thrones-the-laws-of-gods-and-men-annotated
# https://genius.com/Game-of-thrones-mockingbird-annotated
# https://genius.com/Game-of-thrones-the-mountain-and-the-viper-annotated
# https://genius.com/Game-of-thrones-the-watchers-on-the-wall-annotated
# https://genius.com/Game-of-thrones-the-children-annotated
# https://genius.com/Game-of-thrones-season-4-preview-annotated
# https://genius.com/Game-of-thrones-the-wars-to-come-annotated
# https://genius.com/Game-of-thrones-the-house-of-black-and-white-annotated
# https://genius.com/Game-of-thrones-high-sparrow-annotated
# https://genius.com/Game-of-thrones-sons-of-the-harpy-annotated
# https://genius.com/Game-of-thrones-kill-the-boy-annotated
# https://genius.com/Game-of-thrones-unbowed-unbent-unbroken-annotated
# https://genius.com/Game-of-thrones-the-gift-annotated
# https://genius.com/Game-of-thrones-hardhome-annotated
# https://genius.com/Game-of-thrones-the-dance-of-dragons-annotated
# https://genius.com/Game-of-thrones-mothers-mercy-annotated
# https://genius.com/Game-of-thrones-season-5-trailer-breakdown-annotated
# https://genius.com/Game-of-thrones-the-red-woman-annotated
# https://genius.com/Game-of-thrones-home-annotated
# https://genius.com/Game-of-thrones-oathbreaker-annotated
# https://genius.com/Game-of-thrones-book-of-the-stranger-annotated
# https://genius.com/Game-of-thrones-the-door-annotated
# https://genius.com/Game-of-thrones-blood-of-my-blood-annotated
# https://genius.com/Game-of-thrones-the-broken-man-annotated
# https://genius.com/Game-of-thrones-no-one-annotated
# https://genius.com/Game-of-thrones-battle-of-the-bastards-annotated
# https://genius.com/Game-of-thrones-the-winds-of-winter-annotated
# https://genius.com/Game-of-thrones-dragonstone-annotated
# https://genius.com/Game-of-thrones-stormborn-annotated
# https://genius.com/Game-of-thrones-the-queens-justice-annotated
# https://genius.com/Game-of-thrones-the-spoils-of-war-annotated
# https://genius.com/Game-of-thrones-eastwatch-annotated
# https://genius.com/Game-of-thrones-beyond-the-wall-annotated
# https://genius.com/Game-of-thrones-the-dragon-and-the-wolf-annotated
# https://genius.com/Game-of-thrones-winterfell-annotated
# https://genius.com/Game-of-thrones-a-knight-of-the-seven-kingdoms-annotated
# https://genius.com/Game-of-thrones-the-long-night-annotated
# https://genius.com/Game-of-thrones-the-last-of-the-starks-annotated
# https://genius.com/Game-of-thrones-the-bells-annotated
# https://genius.com/Game-of-thrones-the-iron-throne-annotated

# %% [markdown]
# After looking comprehensively at each item in our URL list, we could see there are preview and trailer episodes for both season 4 & 5 which are not needed. Therefore, we will remove those episodes from the list.

# %%
urls = [url for url in urls if 'season' not in url]
len(urls)
# Out:
# 73

# %% [markdown]
# Finally, we have clean and complete list of Game of Thrones' all episodes. Now we can move to scrap the script/conversations from each of those episodes.

# %% [markdown]
# ## Raw Text Scrapping
# In this part we will start scrapping the content contained on each episode URLs that we've found. The data that we want to retrieve from each URL simply consists of:
# * Episode Number
# * Episode Title
# * Season Number
# * Release Date
# * Conversations

# %% [markdown]
# ### Path Finding
# What we gonna do in finding those data is starting with finding the html paths containing each one of the data. After the path found we will transform the data which naturally will be on raw html format to more readable datatypes and store them on predefined variables.
#
# Before we do web scrapping from all the episode URLs, It is better to do the process on one of the URL. Therefore we can find the processes and methods that we can apply to other URLs.
#
# So, we need to save one of our URL in one single variable for further use.

# %%
url = urls[0]
url
# Out:
# 'https://genius.com/Game-of-thrones-winter-is-coming-annotated'

# %% [markdown]
# Similar to previous process, we need to get the HTML response from the URL and store them as `BeautifulSoup` object.

# %%
r = requests.get(url)
html_doc = r.text
soup = BeautifulSoup(html_doc)

# take a look inside
# again only snippet because the result too large
str(soup)[:2000]
# Out:
# '\n<!DOCTYPE html>\n\n<html class="snarly apple_music_player--enabled bagon_song_page--enabled song_stories_public_launch--enabled react_forums--disabled react_song_page--disabled" lang="en" xml:lang="en" xmlns="http://www.w3.org/1999/xhtml" xmlns:fb="http://www.facebook.com/2008/fbml">\n<head>\n<base href="//genius.com/" target="_top"/>\n<script type="text/javascript">\n//<![CDATA[\n\n  var _sf_startpt=(new Date()).getTime();\n  if (window.performance && performance.mark) {\n    window.performance.mark(\'parse_start\');\n  }\n\n//]]>\n</script>\n<title>Game\xa0of Thrones – Winter is Coming | Genius</title>\n<meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>\n<meta content="width=device-width,initial-scale=1" name="viewport"/>\n<meta content="app-id=709482991" name="apple-itunes-app"/>\n<link href="https://assets.genius.com/images/apple-touch-icon.png?1581523915" rel="apple-touch-icon"/>\n<link href="https://assets.genius.com/images/apple-touch-icon.png?1581523915" rel="apple-touch-icon"/>\n<!-- Mobile IE allows us to activate ClearType technology for smoothing fonts for easy reading -->\n<meta content="on" http-equiv="cleartype"/>\n<meta content="f63347d284f184b0" name="y_key"/>\n<meta content="Genius" property="og:site_name">\n<meta content="265539304824" property="fb:app_id">\n<meta content="308252472676410" property="fb:pages">\n<link href="https://genius.com/opensearch.xml" rel="search" title="Genius" type="application/opensearchdescription+xml"/>\n<script>\n!function(){if(\'PerformanceLongTaskTiming\' in window){var g=window.__tti={e:[]};\ng.o=new PerformanceObserver(function(l){g.e=g.e.concat(l.getEntries())});\ng.o.observe({entryTypes:[\'longtask\']})}}();\n</script>\n<script>\n  var CURRENT_USER = null;\n  var CANONICAL_DOMAIN = "genius.com";\n  var CANONICAL_DOMAIN_PARTS_LENGTH = 2;\n  var CURRENT_TAG = {"tag":{"always_allow_personal_annotation":false,"beefy":true,"created_at":"2014-05-22T00:34:21Z","deleted_at":null,"description":"Non-Music is the home of everything non-music on Geniu'

# %% [markdown]
# #### Episode Number & Title
# Based on the HTML text that we loaded above, the episode number and title are wrapped in a `div` tag with class name of `track_listing-track track_listing-track--current`.
# Once again we can easily access this tag using `.find_all()` method.

# %%
episode = soup.find_all('div', class_='track_listing-track track_listing-track--current')
# take a look inside
episode
# Out:
# [<div class="track_listing-track track_listing-track--current">
#  <span class="track_listing-track_number">1.  </span>
#  <span>
#              Winter is Coming
#
#
#            </span>
#  </div>]

# %% [markdown]
# We can see that the result is a list containing a single element of inner HTML from a span. However, the inner HTML itself is still in HTML format. We can get all the texts inside HTML using `.text` attribute of a soup.

# %%
episode = episode[0].text
# take a look inside
episode
# Out:
# '\n1.\xa0\xa0\n\n            Winter is Coming\n            \n            \n          \n'

# %% [markdown]
# Further text processing is needed to get the `number` and `title` of an episode.

# %%
# creating a list by splitting the string using '\n'
episode = episode.split('\n')

# remove unused and empty strings
episode = ''.join(e + ' ' for e in episode)
episode = episode.split(' ')
episode = list(filter(None, episode))

# assign episode number and episode title to different variables
episode_number = ''.join('Episode ' + episode[0].split('.')[0])
episode_title = ''.join(e + ' ' for e in episode[1:])[:-1]

# show the results
print(episode_number)
print(episode_title)
# Out:
# Episode 1
# Winter is Coming

# %% [markdown]
# #### Season Number
# Season number is wrapped in an `a` tag with class name of `song_album-info-title`.

# %%
# get all elements inside 'a' tag, remove enters, convert to list splitted by empty space
season = soup.find_all('a', class_='song_album-info-title')[0].text.replace('\n','').split(' ')

# remove empty strings and concat all the remaining
season = list(filter(None, season))
season = ''.join(s + ' ' for s in season[:-1])[:-1]

print(season)
# Out:
# Season 1

# %% [markdown]
# #### Release Date
# Release date is wrapped in an `span` tag with class name of `metadata_unit-info metadata_unit-info--text_only`.

# %%
# get all elements inside 'a' tag
release_date = soup.find_all('span', class_='metadata_unit-info metadata_unit-info--text_only')
release_date = release_date[0].text

print(release_date)
# Out:
# April 17, 2011

# %% [markdown]
# We want to make the date stored in a more simplified format. We can use method `.strptime()` and `.strftime()` from `datetime`. To do this we need to import `datetime` from package `datetime`.

# %%
from datetime import datetime

release_date = datetime.strptime(release_date, '%B %d, %Y')
release_date = datetime.strftime(release_date, '%Y-%m-%d')

print(release_date)
# Out:
# 2011-04-17

# %% [markdown]
# #### Conversations
# Scrapping the conversations part will have complex and long processes. These processes include getting the raw html text, removing unused tags, filtering the tags needed, and so many text cleansing processes.
#
# As a start, we kno that the conversation part is stored in a `div` tag with class name of `lyrics`

# %%
lyrics = soup.find_all("div", class_="lyrics")[0]

# again only snippet because the result too large
str(lyrics)[:2000]
# Out:
# '<div class="lyrics">\n<!--sse-->\n<p><b>EPISODE 1 - WINTER IS COMING</b></p>\n<hr/><p>[First scene opens with three Rangers riding through a tunnel, leaving the Wall, and going into the woods. (Eerie music in background) One Ranger splits off and finds a campsite full of mutilated bodies, including a child hanging from a tree branch. <a annotation-fragment="1639510" class="referent" classification="accepted" data-id="1639510" href="/Game-of-thrones-winter-is-coming-annotated#note-1639510" image="false" ng-class="{\n          \'referent--linked_to_preview\': song_ctrl.referent_has_preview(fragment_id),\n          \'referent--linked_to_preview_active\': song_ctrl.highlight_preview_referent(fragment_element_id),\n          \'referent--purple_indicator\': song_ctrl.show_preview_referent_indicator(fragment_element_id)\n        }" ng-click="open()" on-hover-with-no-digest="set_current_hover_and_digest(hover ? fragment_id : undefined)" pending-editorial-actions-count="1" prevent-default-click="">A birds-eye view shows the bodies arranged in a shield-like pattern.</a> The Ranger rides back to the other two.]<br/>\n<br/>\n<a annotation-fragment="3326661" class="referent" classification="accepted" data-id="3326661" href="/Game-of-thrones-winter-is-coming-annotated#note-3326661" image="false" ng-class="{\n          \'referent--linked_to_preview\': song_ctrl.referent_has_preview(fragment_id),\n          \'referent--linked_to_preview_active\': song_ctrl.highlight_preview_referent(fragment_element_id),\n          \'referent--purple_indicator\': song_ctrl.show_preview_referent_indicator(fragment_element_id)\n        }" ng-click="open()" on-hover-with-no-digest="set_current_hover_and_digest(hover ? fragment_id : undefined)" pending-editorial-actions-count="0" prevent-default-click="">WAYMAR ROYCE: What d’you expect? They’re savages. One lot steals a goat from another lot and before you know it, they’re ripping each other to pieces.</a><br/>\n<br/>\nWILL: <a annotation-fragment="3354672" class="referent" clas'

# %% [markdown]
# We see there are a lot of tags on our soup. We can easily remove those unused tags using method `.extract()` of a soup. In order to do that we need to convert our soup to a BeautifulSoup object, and then apply the `.extract()` method for each unused tag.

# %%
lyrics = BeautifulSoup(str(lyrics))
[s.extract() for s in lyrics('br')]
[s.extract() for s in lyrics('i')]
[s.extract() for s in lyrics('hr')]
[s.extract() for s in lyrics('h1')]
[s.extract() for s in lyrics('h2')]
[s.extract() for s in lyrics('h3')]

# take a look inside
# again only snippet because the result too large
print(str(lyrics)[:3000])
# Out:
# <div class="lyrics">
# <!--sse-->
# <p><b>EPISODE 1 - WINTER IS COMING</b></p>
# <p>[First scene opens with three Rangers riding through a tunnel, leaving the Wall, and going into the woods. (Eerie music in background) One Ranger splits off and finds a campsite full of mutilated bodies, including a child hanging from a tree branch. <a annotation-fragment="1639510" class="referent" classification="accepted" data-id="1639510" href="/Game-of-thrones-winter-is-coming-annotated#note-1639510" image="false" ng-class="{
#           'referent--linked_to_preview': song_ctrl.referent_has_preview(fragment_id),
#           'referent--linked_to_preview_active': song_ctrl.highlight_preview_referent(fragment_element_id),
#           'referent--purple_indicator': song_ctrl.show_preview_referent_indicator(fragment_element_id)
#         }" ng-click="open()" on-hover-with-no-digest="set_current_hover_and_digest(hover ? fragment_id : undefined)" pending-editorial-actions-count="1" prevent-default-click="">A birds-eye view shows the bodies arranged in a shield-like pattern.</a> The Ranger rides back to the other two.]
#
# <a annotation-fragment="3326661" class="referent" classification="accepted" data-id="3326661" href="/Game-of-thrones-winter-is-coming-annotated#note-3326661" image="false" ng-class="{
#           'referent--linked_to_preview': song_ctrl.referent_has_preview(fragment_id),
#           'referent--linked_to_preview_active': song_ctrl.highlight_preview_referent(fragment_element_id),
#           'referent--purple_indicator': song_ctrl.show_preview_referent_indicator(fragment_element_id)
#         }" ng-click="open()" on-hover-with-no-digest="set_current_hover_and_digest(hover ? fragment_id : undefined)" pending-editorial-actions-count="0" prevent-default-click="">WAYMAR ROYCE: What d’you expect? They’re savages. One lot steals a goat from another lot and before you know it, they’re ripping each other to pieces.</a>
#
# WILL: <a annotation-fragment="3354672" class="referent" classification="accepted" data-id="3354672" href="/Game-of-thrones-winter-is-coming-annotated#note-3354672" image="false" ng-class="{
#           'referent--linked_to_preview': song_ctrl.referent_has_preview(fragment_id),
#           'referent--linked_to_preview_active': song_ctrl.highlight_preview_referent(fragment_element_id),
#           'referent--purple_indicator': song_ctrl.show_preview_referent_indicator(fragment_element_id)
#         }" ng-click="open()" on-hover-with-no-digest="set_current_hover_and_digest(hover ? fragment_id : undefined)" pending-editorial-actions-count="0" prevent-default-click="">I’ve never seen wildlings do a thing like this. I’ve never seen a thing like this, not ever in my life.</a>
#
# WAYMAR ROYCE: How close did you get?
#
# WILL: Close as any man would.
#
# GARED: We should head back to the wall.
#
# <a annotation-fragment="3420725" class="referent" classification="accepted" data-id="3420725" href="/Game-of-thrones-winter-is-coming-annotated#note-3420725" image="false" ng-class="{
#           'referen

# %% [markdown]
# Now we already removed some of unused tags in our `lyrics`. From this we can see that all of the conversations are wrapped in `p` tag and they are clearly written by matching with this pattern `[Person]:[Sentences]`.
#
# However, other text that is not considered as conversation also stored on this tag. So, we need to clean the data again later.

# %%
# get the 'p' tags inner HTML
paragraphs = lyrics.find_all('p')

# create variable to store the conversations
conversations = []

# iterating all 'p' tags found
for p in paragraphs:
    # get the inner text of p, create list by splitting text using '\n', and extend them to list outside the loop
    conversations.extend(p.text.split('\n'))

# %%
# remove empty strings
conversations = list(filter(None, conversations))

# by following the [person]:[sentences] pattern, convert the string inside list to tuple format
conversations = [list(s.split(':')) for s in conversations]

for conversation in conversations[255:266]:
    print(conversation)
# Out:
# ['ILLYRIO', ' Soon. The Dothraki never stay still for long.']
# ['VISERYS', ' Is it true they lie with their horses?']
# ['ILLYRIO', ' I wouldn’t ask Khal Drogo.']
# ['VISERYS', ' Do you take me for a fool?']
# ['ILLYRIO', ' I take you for a king. Kings lack the caution of common men. My apologies if I’ve given offense.']
# ['VISERYS', ' I know how to play a man like Drogo. I give him a queen and he gives me an army.']
# ['DAENERYS (pleadingly) I don’t want to be his queen. I want to go home.']
# ['VISERYS', ' So do I. I want us both to go home. But they took it from us. So tell me, sweet sister, how do we go home?']
# ['DAENERYS', ' I don’t know.']
# ['VISERYS', ' We go home with an army. With Khal Drogo’s army. I would let his whole tribe fuck you, all 40,000 men and their horses too, if that’s what it took.']
# ['[He gives DAENERYS a brotherly kiss on the forehead and walks away. The scene shifts to a bedroom in Winterfell, where CATELYN is fixing SANSA’S hair.]']

# %% [markdown]
# We have all the conversations stored in a list containing tuple of (`person`,`sentence`) format. Unfortunately, some of the entries of our list don't match with the format. This indicates that those values are not considered as a conversation. Therefore we need to remove them.
#
# Now we have two different types of tuple on our list which are tuple consisting 2 values, and tuple consisting only one value. Let's take a look on those two types of tuple.

# %%
for index, conversation in enumerate(conversations[250:270]):
    if len(conversation) >= 2:
        print(str(index) + ' | 2 values | ' + ''.join(str(c) + ':' for c in conversation)[:-1])
    else:
        print(str(index) + ' | 1 value | ' + ''.join(str(c) + ':' for c in conversation)[:-1])
# Out:
# 0 | 2 values | VISERYS: But he didn’t say anything. Did he like her?
# 1 | 2 values | ILLYRIO: Trust me, Your Grace. If he didn’t like her, we’d know.
# 2 | 1 value | [The scene shifts to ILLYRIO, VISERYS, AND DAENERYS ON A GARDEN BALCONY OVERLOOKING THE SEA.]
# 3 | 2 values | ILLYRIO: It won’t be long now. Soon you will cross the Narrow Sea and take back your father’s throne. The people drink secret toasts to your health. They cry out for their true king.
# 4 | 2 values | VISERYS: When will they be married?
# 5 | 2 values | ILLYRIO: Soon. The Dothraki never stay still for long.
# 6 | 2 values | VISERYS: Is it true they lie with their horses?
# 7 | 2 values | ILLYRIO: I wouldn’t ask Khal Drogo.
# 8 | 2 values | VISERYS: Do you take me for a fool?
# 9 | 2 values | ILLYRIO: I take you for a king. Kings lack the caution of common men. My apologies if I’ve given offense.
# 10 | 2 values | VISERYS: I know how to play a man like Drogo. I give him a queen and he gives me an army.
# 11 | 1 value | DAENERYS (pleadingly) I don’t want to be his queen. I want to go home.
# 12 | 2 values | VISERYS: So do I. I want us both to go home. But they took it from us. So tell me, sweet sister, how do we go home?
# 13 | 2 values | DAENERYS: I don’t know.
# 14 | 2 values | VISERYS: We go home with an army. With Khal Drogo’s army. I would let his whole tribe fuck you, all 40,000 men and their horses too, if that’s what it took.
# 15 | 1 value | [He gives DAENERYS a brotherly kiss on the forehead and walks away. The scene shifts to a bedroom in Winterfell, where CATELYN is fixing SANSA’S hair.]
# 16 | 2 values | SANSA: Do you think Joffrey will like me? What if he thinks I’m ugly?
# 17 | 2 values | CATELYN: Then he is the stupidest prince that ever lived.
# 18 | 2 values | SANSA: He’s so handsome.
# 19 | 1 value | [CATELYN rolls her eyes.]

# %%
conversations_md = conversations.copy()

# %%
type(conversations_md)
# Out:
# list

# %%
len(conversations_md)
# Out:
# 431

# %% [markdown]
# To get some visibility into how many scenes and dialogues there are the following code tries to detect scenes.

# %%
changer_expr = ["Scene shifts", "scene shifts", "EXT.", "CUT TO", "INT.", "scene changes", "Scene changes"]
i = 0
for conversation in conversations_md:
        if any(expression in conversation[0] for expression in changer_expr):
                i = i +1
                conversation[0] = conversation[0].replace("["," ").replace("]"," ")
                conversation.insert(0, "ChangeOfScene")

# %%
for index, conversation in enumerate(conversations_md[250:400]):
    if len(conversation) >= 2:
        print(str(index) + ' | 2 values | ' + ''.join(str(c) + ':' for c in conversation)[:-1])
    else:
        print(str(index) + ' | 1 value | ' + ''.join(str(c) + ':' for c in conversation)[:-1])
# Out:
# 0 | 2 values | VISERYS: But he didn’t say anything. Did he like her?
# 1 | 2 values | ILLYRIO: Trust me, Your Grace. If he didn’t like her, we’d know.
# 2 | 2 values | ChangeOfScene: The scene shifts to ILLYRIO, VISERYS, AND DAENERYS ON A GARDEN BALCONY OVERLOOKING THE SEA.
# 3 | 2 values | ILLYRIO: It won’t be long now. Soon you will cross the Narrow Sea and take back your father’s throne. The people drink secret toasts to your health. They cry out for their true king.
# 4 | 2 values | VISERYS: When will they be married?
# 5 | 2 values | ILLYRIO: Soon. The Dothraki never stay still for long.
# 6 | 2 values | VISERYS: Is it true they lie with their horses?
# 7 | 2 values | ILLYRIO: I wouldn’t ask Khal Drogo.
# 8 | 2 values | VISERYS: Do you take me for a fool?
# 9 | 2 values | ILLYRIO: I take you for a king. Kings lack the caution of common men. My apologies if I’ve given offense.
# 10 | 2 values | VISERYS: I know how to play a man like Drogo. I give him a queen and he gives me an army.
# 11 | 1 value | DAENERYS (pleadingly) I don’t want to be his queen. I want to go home.
# 12 | 2 values | VISERYS: So do I. I want us both to go home. But they took it from us. So tell me, sweet sister, how do we go home?
# 13 | 2 values | DAENERYS: I don’t know.
# 14 | 2 values | VISERYS: We go home with an army. With Khal Drogo’s army. I would let his whole tribe fuck you, all 40,000 men and their horses too, if that’s what it took.
# 15 | 2 values | ChangeOfScene: He gives DAENERYS a brotherly kiss on the forehead and walks away. The scene shifts to a bedroom in Winterfell, where CATELYN is fixing SANSA’S hair.
# 16 | 2 values | SANSA: Do you think Joffrey will like me? What if he thinks I’m ugly?
# 17 | 2 values | CATELYN: Then he is the stupidest prince that ever lived.
# 18 | 2 values | SANSA: He’s so handsome.
# 19 | 1 value | [CATELYN rolls her eyes.]
# 20 | 2 values | SANSA: When would we be married? Soon or do we have to wait?
# 21 | 2 values | CATELYN: Hush now. Your father hasn’t even said yes.
# 22 | 2 values | SANSA: Why would he say no? He’d be the second most powerful man in the kingdoms.
# 23 | 2 values | CATELYN: He’d have to leave home. He’d have to leave me. And so would you.
# 24 | 2 values | SANSA: You left your home to come here. And I’d be queen someday. Please make father say yes.
# 25 | 2 values | CATELYN: Sansa…
# 26 | 2 values | SANSA: Please, please. It’s the only thing I ever wanted.
# 27 | 2 values | ChangeOfScene: Scene shifts to the Winterfell banquet. Laughter, music, KING ROBERT getting bawdy with a wench. CATELYN and CERSEI watch, CATELYN embarrassed for CERSEI, who looks disgusted. Out in the courtyard, JON takes out his frustration on a fencing dummy. His uncle BENJEN rides up.
# 28 | 2 values | BENJEN: Is he dead yet?
# 29 | 2 values | JON: Uncle Benjen!
# 30 | 1 value | [They hug.]
# 31 | 2 values | BENJEN: You got bigger. I rode all day. Didn’t want to leave you alone with the Lannisters. Why aren’t you at the feast?
# 32 | 2 values | JON: Lady Stark thought it might insult the royal family to seat a bastard in their midst.
# 33 | 2 values | BENJEN: Well, you’re always welcome on the wall. No bastard was ever refused a seat there.
# 34 | 2 values | JON: So take me with you when you go back.
# 35 | 2 values | BENJEN: Jon…
# 36 | 2 values | JON: Father will let me if you ask him, I know he will.
# 37 | 2 values | BENJEN: The Wall isn’t going anywhere.
# 38 | 2 values | JON: I’m ready to swear your oath.
# 39 | 2 values | BENJEN: You don’t understand what you’d be giving up. We have no families. None of us will ever father sons.
# 40 | 2 values | JON: I don’t care about that.
# 41 | 2 values | BENJEN: You might, if you knew what it meant. … I’d better get inside. Rescue your father from his guests. We’ll talk later.
# 42 | 1 value | [BENJEN goes to the banquet.]
# 43 | 2 values | TYRION: Your uncle’s in the Night’s Watch.
# 44 | 2 values | JON: What’re you doing back there?
# 45 | 2 values | TYRION (drinking): Preparing for a night with your family. I’ve always wanted to see the Wall.
# 46 | 2 values | JON: You’re Tyrion Lannister. The queen’s brother?
# 47 | 2 values | TYRION: My greatest accomplishment. You – you’re Ned Stark’s bastard, aren’t you?
# 48 | 1 value | [JON looks angry and turns away.]
# 49 | 2 values | TYRION: Did I offend you? Sorry. You are the bastard, though.
# 50 | 2 values | JON: Lord Eddard Stark is my father.
# 51 | 2 values | TYRION: And Lady Stark is not your mother. Making you a bastard. Let me give you some advice, bastard. Never forget what you are. The rest of the world will not. Wear it like armor. Then it can never be used to hurt you.
# 52 | 2 values | JON: What the hell do you know about being a bastard?
# 53 | 2 values | TYRION: All dwarves are bastards in their fathers’ eyes.
# 54 | 1 value | [TYRION departs. JON picks up his sword and attacks the dummy with new ferocity.]
# 55 | 2 values | ChangeOfScene: The scene shifts back to the banquet, in full raucous swing. NED is off to himself; BENJEN comes up to him.
# 56 | 2 values | BENJEN: You at a feast -- It’s like a bear in a trap.
# 57 | 2 values | NED: The boy I beheaded. Did you know him?
# 58 | 2 values | BENJEN: Of course I did. Just a lad. But he was tough, Ned. A true Ranger.
# 59 | 2 values | NED: He was talking madness. Said the Walkers slaughtered his friends.
# 60 | 2 values | BENJEN: The two he was with are still missing.
# 61 | 2 values | NED: A wildling ambush.
# 62 | 2 values | BENJEN: Maybe. Direwolves south of the wall. Talk of the Walkers. My brother might be the next Hand to the king. Winter is coming.
# 63 | 2 values | NED: Winter is coming.
# 64 | 1 value | [ROBB approaches.]
# 65 | 2 values | ROBB: Uncle Benjen.
# 66 | 2 values | BENJEN: Robb boy. How are ye?
# 67 | 2 values | ROBB: I’m good.
# 68 | 1 value | [KING ROBERT gets even more bawdy with a wench.]
# 69 | 1 value | CATELYN (in desperation) Is this your first time in the North, Your Grace?
# 70 | 2 values | CERSEI: Yes. Lovely country.
# 71 | 1 value | [They observe SANSA.]
# 72 | 2 values | CATELYN: I’m sure it’s very grim, after Kings Landing. I remember how scared I was when Ned brought me up here for the first time.
# 73 | 1 value | [SANSA approaches and smiles shyly at CERSEI.]
# 74 | 2 values | CERSEI: Hello, little dove. But you are a beauty. How old are you?
# 75 | 2 values | SANSA: Thirteen, Your Grace.
# 76 | 2 values | CERSEI: You’re tall. Still growing?
# 77 | 2 values | SANSA: I think so, Your Grace.
# 78 | 2 values | CERSEI: And have you bled yet?
# 79 | 2 values | SANSA (discomfited): No, Your Grace.
# 80 | 2 values | CERSEI: And your dress. Did you make it?
# 81 | 1 value | [SANSA nods yes.]
# 82 | 2 values | CERSEI: Such talent. You must make something for me.
# 83 | 1 value | [SANSA departs.]
# 84 | 2 values | CERSEI (to CATELYN): I hear we might share a grandchild someday.
# 85 | 2 values | CATELYN: I hear the same.
# 86 | 2 values | CERSEI: Your daughter will do well in the capital. Such a beauty shouldn’t stay hidden up here forever.
# 87 | 1 value | [SANSA and JOFFREY catch each other’s eye. JOFFREY smiles at her and she turns to her friend.]
# 88 | 1 value | [JAIME and NED meet up. JAIME blocks their path.]
# 89 | 2 values | NED: Your pardon.
# 90 | 2 values | JAIME: I hear we might be neighbors soon. I hope it’s true.
# 91 | 2 values | NED: Yes, the king has honored me with his offer.
# 92 | 2 values | JAIME: I’m sure we’ll have a tournament to celebrate the new title, if you accept. It would be good to have you in the field. The competition has become a bit stale.
# 93 | 2 values | NED: I don’t fight in tournaments.
# 94 | 2 values | JAIME: No? Getting a little old for it?
# 95 | 2 values | NED: I don’t fight in tournaments because when I fight a man for real, I don’t want him to know what I can do.
# 96 | 2 values | JAIME: Well said.
# 97 | 1 value | [ARYA flips food onto SANSA’s face.]
# 98 | 2 values | SANSA: Arya!
# 99 | 1 value | [CATELYN signals a laughing ROBB to deal with the girls. He hoists up ARYA.]
# 100 | 2 values | ROBB: Time for bed.
# 101 | 2 values | ChangeOfScene: The scene shifts to after the banquet. NED and CATELYN are in their bed.
# 102 | 2 values | NED: I’m a Northman. I belong here with you, not down south in that rat’s nest they call a capital.
# 103 | 2 values | CATELYN: I won’t let him take you.
# 104 | 2 values | NED: The king takes what he wants. That’s why he’s king.
# 105 | 2 values | CATELYN: I’ll say, ‘Listen, fat man, you are not taking my husband anywhere. He belongs to me now.’
# 106 | 2 values | NED: How did he get so fat?
# 107 | 2 values | CATELYN: He only stops eating when it’s time for a drink.
# 108 | 1 value | [There’s a knock at the door.]
# 109 | 2 values | A VOICE: It’s Maester Luwin, my lord.
# 110 | 2 values | NED: Send him in.
# 111 | 2 values | LUWIN: Pardon, my lord, my lady. A rider in the night from your sister.
# 112 | 1 value | [He hands CATELYN a sealed note.]
# 113 | 2 values | NED: Stay.
# 114 | 2 values | CATELYN: This was sent from the Eyrie. What’s she doing at the Eyrie? She hasn’t been back there since her wedding.
# 115 | 1 value | [CATELYN reads the note, looks up in alarm, and then burns it.]
# 116 | 2 values | NED: What news?
# 117 | 2 values | CATELYN: She’s fled the capital. She says Jon Arryn was murdered. By the Lannisters. She says the king is in danger.
# 118 | 2 values | NED: She’s fresh widowed, Cat. She doesn’t know what she’s saying.
# 119 | 2 values | CATELYN: Lysa’s head would be on a spike right now if the wrong people had found that letter. Do you think she would risk her life, her son’s life, if she wasn’t certain her husband was murdered?
# 120 | 2 values | LUWIN: If this news is true, and the Lannisters conspire against the throne, who but you can protect the king?
# 121 | 2 values | CATELYN: They murdered the last Hand. Now you want Ned to take the job.
# 122 | 2 values | LUWIN: The king rode for a month to ask Lord Stark’s help. He’s the only one he trusts. You swore the king an oath, my lord.
# 123 | 2 values | CATELYN: He spent half his life fighting Robert’s wars. He owes him nothing. (To NED) Your father and brother rode south once on a king’s demand.
# 124 | 2 values | LUWIN: A different time. Different king.
# 125 | 2 values | ChangeOfScene: The scene shifts to the wild wedding celebration of KHAL DROGO and DAENERYS. Fighting and fornication. DAENERYS looks stricken at everything around her.
# 126 | 2 values | VISERYS: When do I meet with the Khal? We need to begin planning the invasion.
# 127 | 2 values | ILLYRIO: If Khal Drogo has promised you a crown, you shall have it.
# 128 | 2 values | VISERYS: When?
# 129 | 2 values | ILLYRIO: When their omens favor war.
# 130 | 2 values | VISERYS: I piss on Dothraki omens. I waited 17 years to get my throne back.
# 131 | 1 value | [The sex and violence intensify. Two men fight to the death over a woman each is trying to rape. KHAL DROGO watches avidly.]
# 132 | 2 values | ILLYRIO: A Dothraki wedding without at least three deaths is considered a dull affair.
# 133 | 1 value | [A knight in Westerosi garb appears. KHAL DROGO greets him in Dothraki. It is JORAH MORMONT, bearing books.]
# 134 | 2 values | JORAH: A small gift for the new Khaleesi. Songs and histories from the Seven Kingdoms.
# 135 | 2 values | DAENERYS: Thank you, ser. Are you from my country?
# 136 | 2 values | JORAH: Ser Jorah Mormont of Bear Island. I served your father for many years. Gods be good, I hope to always serve the rightful king.
# 137 | 1 value | [DANY is presented with a chest with three dragon eggs in it.]
# 138 | 2 values | ILLYRIO: Dragons’ eggs, Daenerys. From the Shadow Lands beyond Asshai. The ages have turned them to stone, but they will always be beautiful.
# 139 | 2 values | DAENERYS: Thank you, Magister.
# 140 | 1 value | [KHAL DROGO rises and strides forward. DAENERYS follows him, looking sick with fear. The Dothraki crowd behind her as she goes. The KHAL leads her to a white mare.]
# 141 | 2 values | DAENERYS: She’s beautiful. … Ser Jorah, I don’t know how to say ‘thank you’ in Dothraki.
# 142 | 2 values | JORAH: There is no word for ‘thank you’ in Dothraki.
# 143 | 1 value | [The KHAL puts DANY on her horse and mounts his.]
# 144 | 2 values | VISERYS: Make him happy.
# 145 | 2 values | ChangeOfScene: The scene shifts to the seaside at sunset. The KHAL begins to unwrap DANY’s dress. She is sobbing. He touches the tears on her face.
# 146 | 2 values | KHAL DROGO: No.
# 147 | 2 values | DAENERYS: Do you know the Common Tongue?
# 148 | 2 values | KHAL DROGO: No.
# 149 | 2 values | DAENERYS: Is ‘no’ the only word that you know?

# %% [markdown]
# Ideally, we can just remove the tuple that only consisting 1 value and store the rest of tuples as our clean data. However, It turns out that some of the conversations actually are not following the `[person]:[sentences]` format. We need to do some `regex` matching in order not to lose those conversations.
#
# But before doing that, we need to remove tuples that represent background situation. Those tuples have elements written inside a bracket `[]`. We can remove those tuples using some `regex` matching. For a better understanding about `regex`, you can do exercise here: https://regexr.com/

# %%
import re
# regex to find conversations in [ some text ] format
regex = '(.+)\[.+\](.+)|(.+)\[.+\]|\[.+\]'
pattern = re.compile(regex)

for index, conversation in enumerate(conversations):
    if len(conversation) <= 1:
        match = pattern.findall(conversation[0])
        if len(match) > 0:
            conversations[index] = tuple((''.join(e + ' ' for e in list(filter(None, match[0]))).replace('    ',' ').replace('   ',' ').replace('  ', ' ')).split('\n'))

conversations = list(filter(None, conversations))
conversations = [c for c in conversations if len(c[0]) > 0]

# show
conversations[15:25]
# Out:
# [['GARED', ' It’s …'],
#  ['ChangeOfScene',
#   ' As he speaks, a CREATURE with glowing blue eyes rises behind ROYCE. ROYCE turns, the CREATURE strikes. The scene shifts to WILL, who hears a man crying out. The three horses stampede past him. He turns and sees someone standing very still in the distance. The figure turns – it’s the child who had been suspended in the tree, now with glowing blue eyes. WILL turns and runs.'],
#  ['GARED is also fleeing, and we hear strange growls and catch glimpses of the CREATURE. Both terrified RANGERS stop, some distance apart, to catch their breath. WILL sees a CREATURE behead GARED. WILL sinks to his knees and the CREATURE tosses GARED’S head to him.]'],
#  ['ChangeOfScene',
#   ' Riders from Winterfell come up behind a dazed WILL. The scene shifts to the castle, where BRAN is practicing archery and getting frustrated, under the eyes of JON SNOW and ROBB STARK. JON pats BRAN’S shoulder. '],
#  ['JON', ' Go on. Father’s watching.'],
#  ['JON', ' And your mother.'],
#  ['ChangeOfScene',
#   ' Scene shifts to needlework practice with the girls inside the castle. '],
#  ['SEPTA MORDANE (to SANSA)', ' Fine work, as always. Well done.'],
#  ['SANSA', ' Thank you.'],
#  ['SEPTA MORDANE',
#   ' I love the detail that you’ve managed to get in this corners. … Quite beautiful … the stitching …']]

# %% [markdown]
# Eventhough we already filtered some of the background situations, there are some cases in which the background situation is divided to two different lines which are not captured by our regex before. We need to clean the list again.

# %%
# regex that match for '[ some text' and 'some text ]' format
regex = '^\[.+|.+\]$'
pattern = re.compile(regex)

for index, conversation in enumerate(conversations):
    if len(conversation) <= 1:
        match = pattern.search(conversation[0])
        if match:
            conversations[index] = None

conversations = list(filter(None, conversations))
conversations[15:25]
# Out:
# [['GARED', ' It’s …'],
#  ['ChangeOfScene',
#   ' As he speaks, a CREATURE with glowing blue eyes rises behind ROYCE. ROYCE turns, the CREATURE strikes. The scene shifts to WILL, who hears a man crying out. The three horses stampede past him. He turns and sees someone standing very still in the distance. The figure turns – it’s the child who had been suspended in the tree, now with glowing blue eyes. WILL turns and runs.'],
#  ['ChangeOfScene',
#   ' Riders from Winterfell come up behind a dazed WILL. The scene shifts to the castle, where BRAN is practicing archery and getting frustrated, under the eyes of JON SNOW and ROBB STARK. JON pats BRAN’S shoulder. '],
#  ['JON', ' Go on. Father’s watching.'],
#  ['JON', ' And your mother.'],
#  ['ChangeOfScene',
#   ' Scene shifts to needlework practice with the girls inside the castle. '],
#  ['SEPTA MORDANE (to SANSA)', ' Fine work, as always. Well done.'],
#  ['SANSA', ' Thank you.'],
#  ['SEPTA MORDANE',
#   ' I love the detail that you’ve managed to get in this corners. … Quite beautiful … the stitching …'],
#  ['NED',
#   ' And which one of you was a marksman at ten? Keep practicing, Bran. Go on.']]

# %% [markdown]
# Now we have filtered all of the background situations, our list now should contains conversations only. However, we still have not do anything about the conversations that is not following the `[person]:[sentence]` format.
#
# Let's take a look at them.

# %%
for index, conversation in enumerate(conversations):
    if len(conversation) < 2:
        print(str(index) + ' | ' + conversation[0])
# Out:
# 0 | EPISODE 1 - WINTER IS COMING
# 40 | NED nods yes, and WILL is positioned on the tree limb that serves as a block.
# 140 | ROBERT (to BRAN) Ooh. Show us your muscles. You’ll be a soldier.
# 202 | VISERYS (to DAENERYS) Do you see how long his hair is? When Dothraki are defeated in combat, they cut off their braid so the whole world can see their shame. Khal Drogo has never been defeated. He’s a savage, of course, but he’s one of the finest killers alive. And you will be his queen.
# 217 | DAENERYS (pleadingly) I don’t want to be his queen. I want to go home.
# 268 | CATELYN (in desperation) Is this your first time in the North, Your Grace?
# 353 | .
# 356 | / BLACKOUT /

# %% [markdown]
# If we look closely, these conversations match the pattern `[person in uppercase] (some text) [sentences]`. Besides, there can also be some conversations that do not have the `(some text)` part.
#
# Once again, we will extract the `person` and `sentence` from those conversations using `regex`.

# %%
# regex to match with '[person in uppercase] [rest of the text]' and '[person in uppercase] (some text) [rest of the text]' format
regex = '^([A-Z]{2,})(.+)'
pattern = re.compile(regex)

for index, conversation in enumerate(conversations):
    if len(conversation) <= 1:
        match = pattern.findall(conversation[0])
        if len(match) > 0:
            conversations[index] = (match[0][0], match[0][-1])
    
# take a look
conversations[125:135]
# Out:
# [['CATELYN',
#   ' You always look at your feet before you lie. Run and find your father. Tell him the king is close.'],
#  ['ChangeOfScene',
#   ' Scene shifts to grand entry of the king’s horses and men. ARYA, wearing a helm and cloak, pushes her way into a tall wagon for a better look. In rides JOFFREY, followed by the HOUND. The other Starks wait in a greeting line. '],
#  ['CATELYN', ' Where’s Arya? Sansa, where’s your sister?'],
#  ['NED',
#   ' Hey,, hey, hey, hey. What are you doing with that on? [Pulls off ARYA’s helm]'],
#  ['ARYA (pushing BRAN)', ' Move!'],
#  ['NED', ' Your Grace.'],
#  ['ROBERT', ' You’ve got fat.'],
#  ['ROBERT', ' Cat!'],
#  ['CATELYN', ' Your Grace.'],
#  ['ROBERT',
#   ' Nine years. Why haven’t I seen you? Where the hell have you been?']]

# %% [markdown]
# At this point we have all the conversations on desired format. Now our list of `conversations` should only have conversation on two valued tuple.

# %%
for conversation in conversations:
    if len(conversation) < 2:
        print(conversation)
# Out:
# ['.']
# ['/ BLACKOUT /']

# %% [markdown]
# We can now take out all of the one valued tuples from our list.

# %%
conversations = [conversation for conversation in conversations if len(conversation) > 1]

# take a look
conversations[:10]
# Out:
# [('EPISODE', ' 1 - WINTER IS COMING'),
#  ['WAYMAR ROYCE',
#   ' What d’you expect? They’re savages. One lot steals a goat from another lot and before you know it, they’re ripping each other to pieces.'],
#  ['WILL',
#   ' I’ve never seen wildlings do a thing like this. I’ve never seen a thing like this, not ever in my life.'],
#  ['WAYMAR ROYCE', ' How close did you get?'],
#  ['WILL', ' Close as any man would.'],
#  ['GARED', ' We should head back to the wall.'],
#  ['ROYCE', ' Do the dead frighten you?'],
#  ['GARED',
#   ' Our orders were to track the wildlings. We tracked them. They won’t trouble us no more.'],
#  ['ROYCE',
#   ' You don’t think he’ll ask us how they died? Get back on your horse.'],
#  ['WILL',
#   ' Whatever did it to them could do it to us. They even killed the children.']]

# %% [markdown]
# Finally, we have our desired list of conversations which is the last piece of data that we want to scrap. From now on we will combine all of the data that we already gathered which are `episode number`, `episode title`, `season number`, `release date`, and `conversation`. We will put all these data together and store them in a `dataframe`.

# %% [markdown]
# #### Create Dataframe
# For creating dataframe we need to import the required package.

# %%
import pandas as pd

# %% [markdown]
# To make a better and tidier dataframe, we can not put raw tuples as our entry. Therefore we need to separate our conversations data as two different set of values which are `person` and `sentence`. We are going to create pandas `Series` for each of them.

# %%
person = pd.Series([c[0] for c in conversations])
sentence = pd.Series([c[1] for c in conversations])

# %% [markdown]
# Let's have a quick look.

# %%
print(person.head())
print(sentence.head())
# Out:
# 0         EPISODE
# 1    WAYMAR ROYCE
# 2            WILL
# 3    WAYMAR ROYCE
# 4            WILL
# dtype: object
# 0                                 1 - WINTER IS COMING
# 1     What d’you expect? They’re savages. One lot s...
# 2     I’ve never seen wildlings do a thing like thi...
# 3                               How close did you get?
# 4                              Close as any man would.
# dtype: object

# %% [markdown]
# Now we have all the separated data in different variables. We can now wrap all of these variables to a single dataframe.

# %%
script = pd.DataFrame({
    'Season': season,
    'Episode': episode_number,
    'Episode Title': episode_title,
    'Sentence': sentence,
    'Name': person,
    'Release Date': release_date
})
script = script[['Release Date','Season','Episode','Episode Title','Name','Sentence']]
print(script.info())
script.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 355 entries, 0 to 354
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Release Date   355 non-null    object
#  1   Season         355 non-null    object
#  2   Episode        355 non-null    object
#  3   Episode Title  355 non-null    object
#  4   Name           355 non-null    object
#  5   Sentence       355 non-null    object
# dtypes: object(6)
# memory usage: 16.8+ KB
# None
#   Release Date    Season    Episode     Episode Title          Name  \
# 0   2011-04-17  Season 1  Episode 1  Winter is Coming       EPISODE
# 1   2011-04-17  Season 1  Episode 1  Winter is Coming  WAYMAR ROYCE
# 2   2011-04-17  Season 1  Episode 1  Winter is Coming          WILL
# 3   2011-04-17  Season 1  Episode 1  Winter is Coming  WAYMAR ROYCE
# 4   2011-04-17  Season 1  Episode 1  Winter is Coming          WILL
#
#                                             Sentence
# 0                               1 - WINTER IS COMING
# 1   What d’you expect? They’re savages. One lot s...
# 2   I’ve never seen wildlings do a thing like thi...
# 3                             How close did you get?
# 4                            Close as any man would.

# %% [markdown]
# We can still see there are some data that considered dirty in this dataframe. On the top position we have data with Name `EPISODE` and Sentence `1 - WINTER IS COMING`. Other case is different representation of same person, such as `DAENERYS` and `DAENERYS TARGARYEN`. There are still some other cases as well. However, we will clean this later on `Post Scrapping Data Cleansing` part. For now we already have at least all of the conversation with no loss and in our desired format.

# %% [markdown]
# ### Wrap The Process in Functions
# Based on what we have done before, we already know how to scrap and gather all the data required to make a dataframe of conversations from one episode of Game of Thrones. We can now iterate all of the episode `URLs` and do the whole process to each of them to get all of the scripts.
#
# However, instead of putting the whole process inside a single loop, it is better to wrap each of the independent process in different functions.

# %% [markdown]
# #### Get Episode

# %%
def get_episode(soup):
    episode = soup.find_all('div', class_='track_listing-track track_listing-track--current')[0].text.split('\n')
    episode = ''.join(e + ' ' for e in episode)
    episode = episode.split(' ')
    episode = list(filter(None, episode))

    episode_number = ''.join('Episode ' + episode[0].split('.')[0])
    episode_title = ''.join(e + ' ' for e in episode[1:])[:-1]
    
    return episode_number, episode_title

# %% [markdown]
# #### Get Season

# %%
def get_season(soup):
    season = soup.find_all('a', class_='song_album-info-title')[0].text.replace('\n','').split(' ')
    season = list(filter(None, season))
    season = ''.join(s + ' ' for s in season[:-1])[:-1]
    
    return season

# %% [markdown]
# #### Get Release Date

# %%
from datetime import datetime

def get_release_date(soup):
    release_date = soup.find_all('span', class_='metadata_unit-info metadata_unit-info--text_only')[0].text
    release_date = datetime.strptime(release_date, '%B %d, %Y')
    release_date = datetime.strftime(release_date, '%Y-%m-%d')
    
    return release_date

# %% [markdown]
# #### Get Conversations

# %%
import re

def get_conversations(soup):
    lyrics = soup.find_all("div", class_="lyrics")[0]

    lyrics = BeautifulSoup(str(lyrics))
    [s.extract() for s in lyrics('br')]
    [s.extract() for s in lyrics('i')]
    [s.extract() for s in lyrics('hr')]
    [s.extract() for s in lyrics('h1')]
    [s.extract() for s in lyrics('h2')]
    [s.extract() for s in lyrics('h3')]

    paragraphs = lyrics.find_all('p')

    conversations = []

    for p in paragraphs:
        conversations.extend(p.text.split('\n'))

    conversations = list(filter(None, conversations))
    conversations = [list(s.split(':')) for s in conversations]
    
    regex = '(.+)\[.+\](.+)|(.+)\[.+\]|\[.+\]'
    pattern = re.compile(regex)
    
    changer_expr = ["Scene shifts", "scene shifts", "EXT.", "CUT TO", "INT.", "scene changes", "Scene changes"]
    i = 0
    for conversation in conversations:
            if any(expression in conversation[0] for expression in changer_expr):
                    i = i +1
                    conversation[0] = conversation[0].replace("["," ").replace("]"," ")
                    conversation.insert(0, "ChangeOfScene")
    
    for index, conversation in enumerate(conversations):
        if len(conversation) <= 1:
            match = pattern.findall(conversation[0])
            if len(match) > 0:
                conversations[index] = tuple((''.join(e + ' ' for e in list(filter(None, match[0]))).replace('    ',' ').replace('   ',' ').replace('  ', ' ')).split('\n'))
                
    conversations = list(filter(None, conversations))
    conversations = [c for c in conversations if len(c[0]) > 0]
    
    regex = '^\[.+|.+\]$'
    pattern = re.compile(regex)
    
    for index, conversation in enumerate(conversations):
        if len(conversation) <= 1:
            match = pattern.search(conversation[0])
            if match:
                conversations[index] = None
                
    conversations = list(filter(None, conversations))
    
    regex = '^([A-Z]{2,})(.+)'
    pattern = re.compile(regex)
    
    for index, conversation in enumerate(conversations):
        if len(conversation) <= 1:
            match = pattern.findall(conversation[0])
            if len(match) > 0:
                conversations[index] = (match[0][0], match[0][-1])
                
    conversations = [conversation for conversation in conversations if len(conversation) > 1]
    
    return conversations

# %% [markdown]
# #### Create Dataframe

# %%
def create_dataframe(**kwargs):
    
    person = pd.Series([c[0] for c in conversations])
    sentence = pd.Series([c[1] for c in conversations])
    
    script = pd.DataFrame({
        'Season': season,
        'Episode': episode_number,
        'Episode Title': episode_title,
        'Sentence': sentence,
        'Name': person,
        'Release Date': release_date
    })
    
    script = script[['Release Date','Season','Episode','Episode Title','Name','Sentence']]
    
    return script

# %% [markdown]
# ### Iterate All Episodes
# After wrapping all of our independent processes in different functions, next thing we should do is applying these functions to all of our episode `URLs` to get the whole script of Game of Thrones. To do this we will make a simple for loop to iterate all of our `URLs`, and put the functions we have made before inside the loop.

# %%
# initiate an empty list to store dataframes from each episode
scripts = []
for url in urls:
    r = requests.get(url)
    html_doc = r.text
    soup = BeautifulSoup(html_doc)
    
    episode_number, episode_title = get_episode(soup)
    season = get_season(soup)
    release_date = get_release_date(soup)
    conversations = get_conversations(soup)
    
    df_scripts = create_dataframe(episode_number = episode_number, 
                                  episode_title = episode_title,
                                  season = season,
                                  release_date = release_date,
                                  conversations = conversations)
    
    scripts.append(df_scripts)
    print('Script from: ' + url + ' added')
# Out:
# Script from: https://genius.com/Game-of-thrones-winter-is-coming-annotated added
# Script from: https://genius.com/Game-of-thrones-the-kingsroad-annotated added
# Script from: https://genius.com/Game-of-thrones-lord-snow-annotated added
# Script from: https://genius.com/Game-of-thrones-cripples-bastards-and-broken-things-annotated added
# Script from: https://genius.com/Game-of-thrones-the-wolf-and-the-lion-annotated added
# Script from: https://genius.com/Game-of-thrones-a-golden-crown-annotated added
# Script from: https://genius.com/Game-of-thrones-you-win-or-you-die-annotated added
# Script from: https://genius.com/Game-of-thrones-the-pointy-end-annotated added
# Script from: https://genius.com/Game-of-thrones-baelor-annotated added
# Script from: https://genius.com/Game-of-thrones-fire-and-blood-annotated added
# Script from: https://genius.com/Game-of-thrones-the-north-remembers-annotated added
# Script from: https://genius.com/Game-of-thrones-the-night-lands-annotated added
# Script from: https://genius.com/Game-of-thrones-what-is-dead-may-never-die-annotated added
# Script from: https://genius.com/Game-of-thrones-garden-of-bones-annotated added
# Script from: https://genius.com/Game-of-thrones-the-ghost-of-harrenhal-annotated added
# Script from: https://genius.com/Game-of-thrones-the-old-gods-and-the-new-annotated added
# Script from: https://genius.com/Game-of-thrones-a-man-without-honor-annotated added
# Script from: https://genius.com/Game-of-thrones-the-prince-of-winterfell-annotated added
# Script from: https://genius.com/Game-of-thrones-blackwater-annotated added
# Script from: https://genius.com/Game-of-thrones-valar-morghulis-annotated added
# Script from: https://genius.com/Game-of-thrones-valar-dohaeris-annotated added
# Script from: https://genius.com/Game-of-thrones-dark-wings-dark-words-annotated added
# Script from: https://genius.com/Game-of-thrones-walk-of-punishment-annotated added
# Script from: https://genius.com/Game-of-thrones-and-now-his-watch-is-ended-annotated added
# Script from: https://genius.com/Game-of-thrones-kissed-by-fire-annotated added
# Script from: https://genius.com/Game-of-thrones-the-climb-annotated added
# Script from: https://genius.com/Game-of-thrones-the-bear-and-the-maiden-fair-annotated added
# Script from: https://genius.com/Game-of-thrones-second-sons-annotated added
# Script from: https://genius.com/Game-of-thrones-the-rains-of-castamere-annotated added
# Script from: https://genius.com/Game-of-thrones-mhysa-annotated added
# Script from: https://genius.com/Game-of-thrones-two-swords-annotated added
# Script from: https://genius.com/Game-of-thrones-the-lion-and-the-rose-annotated added
# Script from: https://genius.com/Game-of-thrones-breaker-of-chains-annotated added
# Script from: https://genius.com/Game-of-thrones-oathkeeper-annotated added
# Script from: https://genius.com/Game-of-thrones-first-of-his-name-annotated added
# Script from: https://genius.com/Game-of-thrones-the-laws-of-gods-and-men-annotated added
# Script from: https://genius.com/Game-of-thrones-mockingbird-annotated added
# Script from: https://genius.com/Game-of-thrones-the-mountain-and-the-viper-annotated added
# Script from: https://genius.com/Game-of-thrones-the-watchers-on-the-wall-annotated added
# Script from: https://genius.com/Game-of-thrones-the-children-annotated added
# Script from: https://genius.com/Game-of-thrones-the-wars-to-come-annotated added
# Script from: https://genius.com/Game-of-thrones-the-house-of-black-and-white-annotated added
# Script from: https://genius.com/Game-of-thrones-high-sparrow-annotated added
# Script from: https://genius.com/Game-of-thrones-sons-of-the-harpy-annotated added
# Script from: https://genius.com/Game-of-thrones-kill-the-boy-annotated added
# Script from: https://genius.com/Game-of-thrones-unbowed-unbent-unbroken-annotated added
# Script from: https://genius.com/Game-of-thrones-the-gift-annotated added
# Script from: https://genius.com/Game-of-thrones-hardhome-annotated added
# Script from: https://genius.com/Game-of-thrones-the-dance-of-dragons-annotated added
# Script from: https://genius.com/Game-of-thrones-mothers-mercy-annotated added
# Script from: https://genius.com/Game-of-thrones-the-red-woman-annotated added
# Script from: https://genius.com/Game-of-thrones-home-annotated added
# Script from: https://genius.com/Game-of-thrones-oathbreaker-annotated added
# Script from: https://genius.com/Game-of-thrones-book-of-the-stranger-annotated added
# Script from: https://genius.com/Game-of-thrones-the-door-annotated added
# Script from: https://genius.com/Game-of-thrones-blood-of-my-blood-annotated added
# Script from: https://genius.com/Game-of-thrones-the-broken-man-annotated added
# Script from: https://genius.com/Game-of-thrones-no-one-annotated added
# Script from: https://genius.com/Game-of-thrones-battle-of-the-bastards-annotated added
# Script from: https://genius.com/Game-of-thrones-the-winds-of-winter-annotated added
# Script from: https://genius.com/Game-of-thrones-dragonstone-annotated added
# Script from: https://genius.com/Game-of-thrones-stormborn-annotated added
# Script from: https://genius.com/Game-of-thrones-the-queens-justice-annotated added
# Script from: https://genius.com/Game-of-thrones-the-spoils-of-war-annotated added
# Script from: https://genius.com/Game-of-thrones-eastwatch-annotated added
# Script from: https://genius.com/Game-of-thrones-beyond-the-wall-annotated added
# Script from: https://genius.com/Game-of-thrones-the-dragon-and-the-wolf-annotated added
# Script from: https://genius.com/Game-of-thrones-winterfell-annotated added
# Script from: https://genius.com/Game-of-thrones-a-knight-of-the-seven-kingdoms-annotated added
# Script from: https://genius.com/Game-of-thrones-the-long-night-annotated added
# Script from: https://genius.com/Game-of-thrones-the-last-of-the-starks-annotated added
# Script from: https://genius.com/Game-of-thrones-the-bells-annotated added
# Script from: https://genius.com/Game-of-thrones-the-iron-throne-annotated added

# %%
script_dataframe = pd.concat(scripts)
script_dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 26123 entries, 0 to 292
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Release Date   26123 non-null  object
#  1   Season         26123 non-null  object
#  2   Episode        26123 non-null  object
#  3   Episode Title  26123 non-null  object
#  4   Name           26123 non-null  object
#  5   Sentence       26123 non-null  object
# dtypes: object(6)
# memory usage: 1.4+ MB

# %% [markdown]
# Finally, we have collected all scripts for the whole season of Game of Thrones in a single dataframe. However, we still keep in mind that these data are not completely clean yet. That is why what we are going to do next is doing the `Post Scrapping Data Cleansing` to make sure the dataset is safe to use.

# %% [markdown]
# ## Post-Scrapping Data Cleansing

# %%
script_dataframe = script_dataframe.dropna()
script_dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 26123 entries, 0 to 292
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Release Date   26123 non-null  object
#  1   Season         26123 non-null  object
#  2   Episode        26123 non-null  object
#  3   Episode Title  26123 non-null  object
#  4   Name           26123 non-null  object
#  5   Sentence       26123 non-null  object
# dtypes: object(6)
# memory usage: 1.4+ MB

# %% [markdown]
# We have encountered some `Name` and `Sentence` that contain some bracketed strings in previous sections. This can describe about what the person is thinking or refers to the audience of the person talking. We don't need these to ruin our data, therefore we need to remove them.

# %%
import re
def remove_bracketed(text):
    regex = '\([^)]*\)'
    text = re.sub(regex, '', text).replace('  ',' ')
    return text

script_dataframe['Name'] = script_dataframe['Name'].apply(remove_bracketed)
script_dataframe['Sentence'] = script_dataframe['Sentence'].apply(remove_bracketed)

script_dataframe.head(3)
# Out:
#   Release Date    Season    Episode     Episode Title          Name  \
# 0   2011-04-17  Season 1  Episode 1  Winter is Coming       EPISODE
# 1   2011-04-17  Season 1  Episode 1  Winter is Coming  WAYMAR ROYCE
# 2   2011-04-17  Season 1  Episode 1  Winter is Coming          WILL
#
#                                             Sentence
# 0                               1 - WINTER IS COMING
# 1   What d’you expect? They’re savages. One lot s...
# 2   I’ve never seen wildlings do a thing like thi...

# %% [markdown]
# Now we have already eliminated null values on our dataframe and also eliminated bracketed text from column `Name` and `Sentence` on our dataframe.
#
# For further cleansing, we need to make values of our `Name` column homogenous. First thing we need to do to achieve this is making the `Name` column in lowercase text format.

# %%
script_dataframe['Name'] = script_dataframe['Name'].apply(lambda x: str(x).lower())
script_dataframe.head(3)
# Out:
#   Release Date    Season    Episode     Episode Title          Name  \
# 0   2011-04-17  Season 1  Episode 1  Winter is Coming       episode
# 1   2011-04-17  Season 1  Episode 1  Winter is Coming  waymar royce
# 2   2011-04-17  Season 1  Episode 1  Winter is Coming          will
#
#                                             Sentence
# 0                               1 - WINTER IS COMING
# 1   What d’you expect? They’re savages. One lot s...
# 2   I’ve never seen wildlings do a thing like thi...

# %% [markdown]
# After making all names in lowercase format, we need to remove all non-aphabetical character in `Name` column. We can make a simple function to do regex substitution.

# %%
import re
def remove_non_alphabetic(text):
    regex = '[^A-Za-z\s]'
    text = re.sub(regex, '', text).replace('  ',' ')
    text = text if text[-1] != ' ' else text[:-1]
    return text

# %%
script_dataframe['Name'] = script_dataframe['Name'].apply(remove_non_alphabetic)
script_dataframe.head(3)
# Out:
#   Release Date    Season    Episode     Episode Title          Name  \
# 0   2011-04-17  Season 1  Episode 1  Winter is Coming       episode
# 1   2011-04-17  Season 1  Episode 1  Winter is Coming  waymar royce
# 2   2011-04-17  Season 1  Episode 1  Winter is Coming          will
#
#                                             Sentence
# 0                               1 - WINTER IS COMING
# 1   What d’you expect? They’re savages. One lot s...
# 2   I’ve never seen wildlings do a thing like thi...

# %% [markdown]
# We have all names in similar format, in lowercase and only consist of alphabetic characters.The first thing we need to do now is removing the naration text from our dataframe. As we previously known, some of the background conditions which categorized as narations are written in the same format as conversation. Some examples for this case are `EPISODE` and `CUT TO`.
#
# Easiest way to do this is by extracting the first word of each names and put them into a new column. This column will later be used to filter the names.

# %%
script_dataframe['First Token'] = script_dataframe['Name'].apply(lambda x: str(x).split(' ')[0])
script_dataframe.head(3)
# Out:
#   Release Date    Season    Episode     Episode Title          Name  \
# 0   2011-04-17  Season 1  Episode 1  Winter is Coming       episode
# 1   2011-04-17  Season 1  Episode 1  Winter is Coming  waymar royce
# 2   2011-04-17  Season 1  Episode 1  Winter is Coming          will
#
#                                             Sentence First Token
# 0                               1 - WINTER IS COMING     episode
# 1   What d’you expect? They’re savages. One lot s...      waymar
# 2   I’ve never seen wildlings do a thing like thi...        will

# %% [markdown]
# To continue, we will now filter the background conditions from our dataframe. These entries will have `First Token` such as `episode`, `cut`, `int`, and `ext`.

# %%
script_dataframe = script_dataframe[(script_dataframe['First Token'] != 'cut') &
                                    (script_dataframe['First Token'] != 'int') &
                                    (script_dataframe['First Token'] != 'ext') &
                                    (script_dataframe['First Token'] != 'episode')]
script_dataframe.head(3)
# Out:
#   Release Date    Season    Episode     Episode Title          Name  \
# 1   2011-04-17  Season 1  Episode 1  Winter is Coming  waymar royce
# 2   2011-04-17  Season 1  Episode 1  Winter is Coming          will
# 3   2011-04-17  Season 1  Episode 1  Winter is Coming  waymar royce
#
#                                             Sentence First Token
# 1   What d’you expect? They’re savages. One lot s...      waymar
# 2   I’ve never seen wildlings do a thing like thi...        will
# 3                             How close did you get?      waymar

# %% [markdown]
# So we have now filtered all of the backgoud conditions from our dataframe. Let's focus on column `Name` again.
#
# We should check if this column only has normal name as its entries. There are many cases that can be considered as anomaly in person's name, such as name length. For now we will see are there any anomaly length on our `Name` column.

# %%
script_dataframe['Name Length'] = script_dataframe['Name'].apply(lambda x: len(str(x)))
print(script_dataframe['Name Length'].describe(percentiles=[.8,.9,.95,.99,.999,.9999,.99999,.999999]))
print(script_dataframe.info())
print(script_dataframe['Name Length'].value_counts().sort_values().head())
# Out:
# count       25716.000000
# mean            7.066301
# std             3.929052
# min             2.000000
# 50%             6.000000
# 80%             9.000000
# 90%            13.000000
# 95%            13.000000
# 99%            17.000000
# 99.9%          21.000000
# 99.99%         23.000000
# 99.999%       247.140750
# 99.9999%      315.414075
# max           323.000000
# Name: Name Length, dtype: float64
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 25716 entries, 1 to 292
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Release Date   25716 non-null  object
#  1   Season         25716 non-null  object
#  2   Episode        25716 non-null  object
#  3   Episode Title  25716 non-null  object
#  4   Name           25716 non-null  object
#  5   Sentence       25716 non-null  object
#  6   First Token    25716 non-null  object
#  7   Name Length    25716 non-null  int64
# dtypes: int64(1), object(7)
# memory usage: 1.8+ MB
# None
# 28      1
# 323     1
# 20      3
# 22      3
# 23     12
# Name: Name Length, dtype: int64

# %% [markdown]
# Based on information above, we know that most of our value in column `Name` only have length no longer than 28 characters. In fact, as an outlier we have one name that consists of more than 300 characters.
#
# Once again, just like null values on data, there are also many ways to handle outlier values on data. But for this case we will just eliminate the outlier because it only has small number, just one entry to be precise.

# %%
script_dataframe = script_dataframe[script_dataframe['Name Length'] <= 28]
script_dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 25715 entries, 1 to 292
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Release Date   25715 non-null  object
#  1   Season         25715 non-null  object
#  2   Episode        25715 non-null  object
#  3   Episode Title  25715 non-null  object
#  4   Name           25715 non-null  object
#  5   Sentence       25715 non-null  object
#  6   First Token    25715 non-null  object
#  7   Name Length    25715 non-null  int64
# dtypes: int64(1), object(7)
# memory usage: 1.8+ MB

# %% [markdown]
# ### Name Homogenization
# As the next step, we previously know that our `Name` column may have different values for a same person. This can happen because of aliases, family names, nicknames, and others. However, it will take a lot of effort if we make all of our `Name` value homogen. Instead of doing that, we will just make homogen name of characters that matter the most in the data. Now let's see who are those characters that matter the most.

# %%
appearance_counts = script_dataframe.groupby(['Name'])['Sentence'].count().reset_index()
appearance_counts.Sentence.describe(percentiles=[.8,.9,.95,.99,.999])
# Out:
# count     639.000000
# mean       40.242567
# std       129.209627
# min         1.000000
# 50%         5.000000
# 80%        32.000000
# 90%        86.400000
# 95%       187.500000
# 99%       703.960000
# 99.9%    1440.192000
# max      1578.000000
# Name: Sentence, dtype: float64

# %% [markdown]
# Based on information above, we figured that only 10% of the characters have more than 80 different sentences. These characters will we be focused on and made homogen.

# %%
most_sentence_characters = appearance_counts[appearance_counts['Sentence'] > 80].sort_values(by=['Sentence'], ascending=[0])

# %% [markdown]
# Take a peek on the dataset, we will see that characters on this dataset still consist of some universal aliases like `man` and `soldier` which are not owned by a single character, instead used by many different characters. These aliases should be removed from dataset.

# %%
most_sentence_characters = most_sentence_characters[(most_sentence_characters['Name'] != 'man') &
                                                    (most_sentence_characters['Name'] != 'soldier')]

# %% [markdown]
# Now we already removed all of the universal aliases from our character dataframes. Let's take a look of its unique values.

# %%
char_names = most_sentence_characters['Name'].unique()
print('total: ' + str(len(char_names)))
char_names
# Out:
# total: 64
# array(['tyrion', 'changeofscene', 'jon', 'cersei', 'daenerys', 'jaime',
#        'sansa', 'arya', 'davos', 'theon', 'sam', 'bronn', 'varys',
#        'brienne', 'bran', 'tywin', 'jorah', 'stannis', 'margaery',
#        'ramsay', 'melisandre', 'robb', 'eddard stark', 'jon snow', 'shae',
#        'gendry', 'littlefinger', 'joffrey', 'tormund', 'gilly',
#        'tyrion lannister', 'missandei', 'catelyn', 'ygritte', 'olenna',
#        'daario', 'podrick', 'yara', 'the hound', 'osha', 'oberyn',
#        'baelish', 'sandor', 'tommen', 'jaqen', 'grey worm', 'qyburn',
#        'talisa', 'petyr baelish', 'meera', 'catelyn stark', 'samwell',
#        'thoros', 'daenerys targaryen', 'robert baratheon', 'arya stark',
#        'shireen', 'high sparrow', 'beric', 'euron', 'hound',
#        'sansa stark', 'grenn', 'jorah mormont'], dtype=object)

# %% [markdown]
# Only 63 characters with more than 80 sentences (from now on we will address this as `important characters`) are left on our character dataframe. It takes not a big effort for us to manually homogenize the names on this list. Also, notice that some of the characters on this list have other name or alias in the series. We are going to make a mapping for these aliases too.
#
# For now, we will make a new dataframe containing unique name and alias from these characters.

# %%
char_names = ['tyrion lannister', 'jon snow', 'jaime lannister', 'sansa stark', 'arya stark', 'davos',
              'theon greyjoy', 'bronn', 'varys', 'brienne', 'bran stark', 'tywin lannister', 'jorah mormont', 'stannis baratheon',
              'margaery tyrell', 'ramsay bolton', 'melisandre', 'robb stark', 'jon snow', 'shae', 'gendry baratheon',
              'tormund', 'gilly', 'tyrion lannister', 'missandei', 'catelyn stark', 'ygritte', 'olenna tyrell', 'daario',
              'podrick', 'yara greyjoy', 'osha', 'oberyn martell', 'jaqen hghar','grey worm', 'qyburn', 'talisa', 'meera', 'catelyn stark',
              'thoros','robert baratheon', 'arya stark', 'shireen', 'sparrow', 'beric', 'euron greyjoy','sansa stark', 'grenn', 'jorah mormont']

alias_mapper = ['sandor clegane','petyr baelish','petyr baelish','sam tarly','eddard stark','cersei lannister','joffrey lannister',
                'tommen lannister','daenerys targaryen','daenerys targaryen']

alias = ['hound','littlefinger','baelish','samwell tarly','ned stark','cersei baratheon','joffrey baratheon',
         'tommen baratheon','daenerys stormborn','dany']

char_names = sorted(list(pd.Series(char_names).unique()))
char_alias = [None for i in range(0, len(char_names))]
char_names.extend(alias_mapper)
char_alias.extend(alias)
name_dictionary = pd.DataFrame({
    "Base Name": char_names,
    "Alias": char_alias
})

name_dictionary = name_dictionary[['Base Name','Alias']]
name_dictionary = name_dictionary.sort_values(by=['Base Name'])
name_dictionary.head()
# Out:
#     Base Name Alias
# 0  arya stark  None
# 1       beric  None
# 2  bran stark  None
# 3     brienne  None
# 4       bronn  None

# %% [markdown]
# After completing the name dictionary for important characters, the next thing we do is mapping these name to our main dataframe. We will first make a mapper dataframe to be used later for mapping purpose. To do this we need to make a copy of our main dataframe.
#
# But before we make a copy, there are some cases that need to be highlighted. Some of the character aliases contain word like `high` and `the`, for example `high sparrow` and `the hound`. Keeping these words will get us into trouble when scoring the string similarity later because these words will increase the scores two different names that have prefix of these words. Therefore, we need to remove these words from our character names.

# %%
def clean_words(x):
    new_name = x.replace('the ','')
    new_name = new_name.replace('high ', '')
    return new_name

# %%
script_dataframe['Name'] = script_dataframe['Name'].apply(clean_words)

# %% [markdown]
# Now we can start making the mapper for our important characters starting with making a copy of our main dataframe as a new dataframe object.

# %%
script_for_mapper = script_dataframe.copy()

# %% [markdown]
# The first step of creating this mapper is generating a cartesian product of our new dataframe and our important characters dataframe. The easiest way to do this is by creating a column with similar name and values for both dataframe. This column will be used for merging in which we will use this column as a key for doing dataframe left outer merge. We add column `Cartesian Key` with value of `0` for both data frame, and then we do outer merge on those dataframes using the column `Cartesian Key`.

# %%
script_for_mapper['Cartesian Key'] = 0
name_dictionary['Cartesian Key'] = 0
script_for_mapper = script_for_mapper.merge(name_dictionary, on=['Cartesian Key'], how='outer')
script_for_mapper.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1362895 entries, 0 to 1362894
# Data columns (total 11 columns):
#  #   Column         Non-Null Count    Dtype
# ---  ------         --------------    -----
#  0   Release Date   1362895 non-null  object
#  1   Season         1362895 non-null  object
#  2   Episode        1362895 non-null  object
#  3   Episode Title  1362895 non-null  object
#  4   Name           1362895 non-null  object
#  5   Sentence       1362895 non-null  object
#  6   First Token    1362895 non-null  object
#  7   Name Length    1362895 non-null  int64
#  8   Cartesian Key  1362895 non-null  int64
#  9   Base Name      1362895 non-null  object
#  10  Alias          257150 non-null   object
# dtypes: int64(2), object(9)
# memory usage: 124.8+ MB

# %% [markdown]
# Notice that there is massive increase on number of rows of our dataframe. This is happened because of cartesian product basically mapping every rows in first dataframe to every rows in second dataframe. It increases total row by multiplying number of rows of first dataframe by number of rows of second dataframe.
#
# In order to create a proper mapper, we need to make sure that each name of our dataframe is the really the name of our important characters. In this process we will also tackle case of typo writing on our dataframe. To do this we will get similarity score between our character names and the important characters dataset, either the name or the alias.
#
# This algorithm below will do the scoring process. As for the string similarity, after some researches I found that the most suitable algorithm for this is the `Jaro Winkler` algorithm. I will use package from `jellyfish` that contains `Jaro Winkler` algorithm. You can read more about `Jaro Winkler` algorithm here https://en.wikipedia.org/wiki/Jaro%E2%80%93Winkler_distance, and the `jellyfish` documentation here https://jellyfish.readthedocs.io/.

# %%
# !pip install jellyfish
# Out:
# Requirement already satisfied: jellyfish in ./lib/python3.6/site-packages (0.7.2)

# %%
from jellyfish import jaro_winkler

def get_similarity(row):
    current_name = row['Name']
    base_name = row['Base Name']
    alias = row['Alias']
    
    score_base_name = 0
    score_alias = 0
    
    if current_name == base_name:
        score_base_name = 1
    else:
        listed_current_name = current_name.split(' ')
        listed_base_name = base_name.split(' ')
        
        if len(listed_current_name) > 1 and len(listed_base_name) > 1:
            family_name_similarity = jaro_winkler(listed_current_name[1], listed_base_name[1])
            if family_name_similarity > .9:
                score_base_name = jaro_winkler(listed_current_name[0], listed_base_name[0])
            else:
                score_base_name = jaro_winkler(current_name, base_name)
        elif len(listed_base_name) > 1:
            score_base_name = jaro_winkler(current_name, listed_base_name[0])
        else:
            score_base_name = jaro_winkler(current_name, base_name)
        
        if alias != None:
            listed_alias = alias.split(' ')
            if len(listed_current_name) > 1 and len(listed_alias) > 1:
                family_name_similarity = jaro_winkler(listed_current_name[1], listed_alias[1])
                if family_name_similarity > .9:
                    score_base_name = jaro_winkler(listed_current_name[0], listed_alias[0])
                else:
                    score_base_name = jaro_winkler(current_name, alias)
            elif len(listed_alias) > 1:
                score_base_name = jaro_winkler(current_name, listed_alias[0])
            else:
                score_base_name = jaro_winkler(current_name, alias)
    
    return score_base_name if score_base_name > score_alias else score_alias

# %%
script_for_mapper['Name Similarity'] = script_for_mapper.apply(get_similarity, axis=1)

# %% [markdown]
# After some data exploration I found that minimum score for the name similarity that can be accepted as a same character is `0.89`. Therefore, we will make a new name column named `Homogenized Name` and fill them with condition if the similarity score is greater than `0.89` use name from the important character dataset, which in this dataframe stored as `Base Name` column, and for rows with similarity score les than `0.89` use `None`.

# %%
def get_homogenized_name(x):
    similarity = x['Name Similarity']
    name = x['Name']
    base_name = x['Base Name']
    
    if similarity > .89:
        return base_name
    else:
        return None

# %%
script_for_mapper['Homogenized Name'] = script_for_mapper.apply(get_homogenized_name, axis=1)
script_for_mapper.head()
# Out:
#   Release Date    Season    Episode     Episode Title          Name  \
# 0   2011-04-17  Season 1  Episode 1  Winter is Coming  waymar royce
# 1   2011-04-17  Season 1  Episode 1  Winter is Coming  waymar royce
# 2   2011-04-17  Season 1  Episode 1  Winter is Coming  waymar royce
# 3   2011-04-17  Season 1  Episode 1  Winter is Coming  waymar royce
# 4   2011-04-17  Season 1  Episode 1  Winter is Coming  waymar royce
#
#                                             Sentence First Token  Name Length  \
# 0   What d’you expect? They’re savages. One lot s...      waymar           12
# 1   What d’you expect? They’re savages. One lot s...      waymar           12
# 2   What d’you expect? They’re savages. One lot s...      waymar           12
# 3   What d’you expect? They’re savages. One lot s...      waymar           12
# 4   What d’you expect? They’re savages. One lot s...      waymar           12
#
#    Cartesian Key   Base Name Alias  Name Similarity Homogenized Name
# 0              0  arya stark  None         0.644444             None
# 1              0       beric  None         0.427778             None
# 2              0  bran stark  None         0.572222             None
# 3              0     brienne  None         0.484127             None
# 4              0       bronn  None         0.427778             None

# %% [markdown]
# By now, we should have our important characters with both of their `Name` and `Homogenized Name` filled with non null object. Next we will do is extracting the `Name` and `Homogenized Name` columns and dropping the `None` values so that the dataframe only contains name of our important characters.

# %%
script_for_mapper = script_for_mapper[['Name','Homogenized Name']].dropna().drop_duplicates()
script_for_mapper.head()
# Out:
#          Name Homogenized Name
# 921       jon         jon snow
# 1151    sansa      sansa stark
# 1230      ned     eddard stark
# 1359     robb       robb stark
# 1542  catelyn    catelyn stark

# %% [markdown]
# At this point, there is a special case on this mapper. A character named `Robett Glover` is mapped as `Robert Baratheon` on our mapper. This is happened because on the script from `genius.com`, they wrote the name `robett` without the family name. If you read our algorithm for scoring the string similarity, after comparing name of `robett` and `robert` the algorithm will give a high similarity score as result. For this case, I will manually delete the row from our mapper since it is the fastest way for cleaning the table.

# %%
#script_for_mapper = script_for_mapper.drop(1031097)

# %% [markdown]
# Now that we have a clean mapper for our important characters, we can finally map the name in our main dataframe to our important characters mapper dataframe. We can do the mapping by doing a simple pandas left merge on column `Name` of each dataframe.

# %%
script_dataframe = script_dataframe.merge(script_for_mapper, on=['Name'], how='left')
script_dataframe.head()
# Out:
#   Release Date    Season    Episode     Episode Title          Name  \
# 0   2011-04-17  Season 1  Episode 1  Winter is Coming  waymar royce
# 1   2011-04-17  Season 1  Episode 1  Winter is Coming          will
# 2   2011-04-17  Season 1  Episode 1  Winter is Coming  waymar royce
# 3   2011-04-17  Season 1  Episode 1  Winter is Coming          will
# 4   2011-04-17  Season 1  Episode 1  Winter is Coming         gared
#
#                                             Sentence First Token  Name Length  \
# 0   What d’you expect? They’re savages. One lot s...      waymar           12
# 1   I’ve never seen wildlings do a thing like thi...        will            4
# 2                             How close did you get?      waymar           12
# 3                            Close as any man would.        will            4
# 4                   We should head back to the wall.       gared            5
#
#   Homogenized Name
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN

# %% [markdown]
# We now have successfully mapped the name of our important characters to their name on main dataframe. We will now clean the `Name` column by filling them with available value in `Homogenized Name` column, or we can say changing the name of our important characters to their clean name.

# %%
script_dataframe['Homogenized Name'] = script_dataframe['Homogenized Name'].fillna('')
script_dataframe['Name'] = script_dataframe[['Name','Homogenized Name']].apply(lambda x: x[1] if x[1] != '' else x[0], axis=1)
script_dataframe.head()
# Out:
#   Release Date    Season    Episode     Episode Title          Name  \
# 0   2011-04-17  Season 1  Episode 1  Winter is Coming  waymar royce
# 1   2011-04-17  Season 1  Episode 1  Winter is Coming          will
# 2   2011-04-17  Season 1  Episode 1  Winter is Coming  waymar royce
# 3   2011-04-17  Season 1  Episode 1  Winter is Coming          will
# 4   2011-04-17  Season 1  Episode 1  Winter is Coming         gared
#
#                                             Sentence First Token  Name Length  \
# 0   What d’you expect? They’re savages. One lot s...      waymar           12
# 1   I’ve never seen wildlings do a thing like thi...        will            4
# 2                             How close did you get?      waymar           12
# 3                            Close as any man would.        will            4
# 4                   We should head back to the wall.       gared            5
#
#   Homogenized Name
# 0
# 1
# 2
# 3
# 4

# %% [markdown]
# Finally, we managed to map and homogenize the name of our important characters. Let's restore our main dataframe to its orginal format and remove the duplicated values.

# %%
script_dataframe = script_dataframe[['Release Date','Season','Episode','Episode Title','Name','Sentence']].drop_duplicates()
script_dataframe.head()
# Out:
#   Release Date    Season    Episode     Episode Title          Name  \
# 0   2011-04-17  Season 1  Episode 1  Winter is Coming  waymar royce
# 1   2011-04-17  Season 1  Episode 1  Winter is Coming          will
# 2   2011-04-17  Season 1  Episode 1  Winter is Coming  waymar royce
# 3   2011-04-17  Season 1  Episode 1  Winter is Coming          will
# 4   2011-04-17  Season 1  Episode 1  Winter is Coming         gared
#
#                                             Sentence
# 0   What d’you expect? They’re savages. One lot s...
# 1   I’ve never seen wildlings do a thing like thi...
# 2                             How close did you get?
# 3                            Close as any man would.
# 4                   We should head back to the wall.

# %% [markdown]
# ### Sentence Cleansing
# Case that most likely occured on column `Sentence` is not as much as in `Name` column. One of the reason is because we already clean some of them on `Name` cleansing process.
#
# However there are still cases that make our the `Sentence` column still contains dirty data. First case is the sentence is not properly started meaning that first character on the sentence is a non-aphanumeric character. This can happen because of our previous cleansing in which we remove the bracketed text on our `Name` and `Sentence` columns. Next case is the sentence written in differen format than most of them, or to be specific some sentences are written inside quote `''` or double quote `""`, while others are not. The last case is sentences that contain empty string which might also happen because of removing of the bracketed texts.
#
# The function below contains algorithm that is going to handle the non-proper form sentences.

# %%
import re
def clean_sentence(text):
    
    text_list = text.split(' ')
    
    if len(text_list) > 1:
        text = ''.join(' ' + word for word in text_list if word != '')[1:].replace('    ',' ').replace('   ',' ').replace('  ',' ')
        if len(text) > 1:
            text = text[:-1] if text[-1] == ' ' else text
            if text[0] == '"' and text[-1] == '"':
                text = text[1:-1]
            if text[0] == '\'' and text[-1] == '\'':
                text = text[1:-1]

        regex = '^[^A-Za-z0-9]*'
        text = re.sub(regex, '', text).replace('  ',' ')
        if len(text) > 0:
            text = text if text[-1] != ' ' else text[:-1]
    
    return text

# %%
script_dataframe['Clean Sentence'] = script_dataframe['Sentence'].apply(clean_sentence)
script_dataframe.head(3)
# Out:
#   Release Date    Season    Episode     Episode Title          Name  \
# 0   2011-04-17  Season 1  Episode 1  Winter is Coming  waymar royce
# 1   2011-04-17  Season 1  Episode 1  Winter is Coming          will
# 2   2011-04-17  Season 1  Episode 1  Winter is Coming  waymar royce
#
#                                             Sentence  \
# 0   What d’you expect? They’re savages. One lot s...
# 1   I’ve never seen wildlings do a thing like thi...
# 2                             How close did you get?
#
#                                       Clean Sentence
# 0  What d’you expect? They’re savages. One lot st...
# 1  I’ve never seen wildlings do a thing like this...
# 2                             How close did you get?

# %% [markdown]
# Now the `Sentence` column values should all be in the same format. The last case that needed to be handled is the empty string. We can easily handle this by making a new column that contains value of the lenght of each `Sentence` value in our main dataframe. And then use the column to filter empty strings.

# %%
script_dataframe['Length Sentence'] = script_dataframe['Clean Sentence'].apply(len)
script_dataframe = script_dataframe[script_dataframe['Length Sentence'] > 1]
script_dataframe.head(3)
# Out:
#   Release Date    Season    Episode     Episode Title          Name  \
# 0   2011-04-17  Season 1  Episode 1  Winter is Coming  waymar royce
# 1   2011-04-17  Season 1  Episode 1  Winter is Coming          will
# 2   2011-04-17  Season 1  Episode 1  Winter is Coming  waymar royce
#
#                                             Sentence  \
# 0   What d’you expect? They’re savages. One lot s...
# 1   I’ve never seen wildlings do a thing like thi...
# 2                             How close did you get?
#
#                                       Clean Sentence  Length Sentence
# 0  What d’you expect? They’re savages. One lot st...              136
# 1  I’ve never seen wildlings do a thing like this...              103
# 2                             How close did you get?               22

# %% [markdown]
# We already have a clean sentence and also removed all empty strings on our dataframe. Now we should replace values on `Sentence` column using the values on `Clean Sentence` column and then restore our dataframe to its original structure.

# %%
script_dataframe['Sentence'] = script_dataframe['Clean Sentence']
script_dataframe = script_dataframe[['Release Date','Season','Episode','Episode Title','Name','Sentence']].drop_duplicates()
script_dataframe.head()
# Out:
#   Release Date    Season    Episode     Episode Title          Name  \
# 0   2011-04-17  Season 1  Episode 1  Winter is Coming  waymar royce
# 1   2011-04-17  Season 1  Episode 1  Winter is Coming          will
# 2   2011-04-17  Season 1  Episode 1  Winter is Coming  waymar royce
# 3   2011-04-17  Season 1  Episode 1  Winter is Coming          will
# 4   2011-04-17  Season 1  Episode 1  Winter is Coming         gared
#
#                                             Sentence
# 0  What d’you expect? They’re savages. One lot st...
# 1  I’ve never seen wildlings do a thing like this...
# 2                             How close did you get?
# 3                            Close as any man would.
# 4                   We should head back to the wall.

# %% [markdown]
# For the final touch, it might be hard to notice but quote symbol in `Sentence` column is using `’` instead of `'`. A simple regex replace can fix this problem. While we are doing this, we can as well replace the `d’` word that can easily be seen on the first row. This is actually a simple alternative for word `do`. Again, we will use regex replace to fix them.

# %%
script_dataframe['Sentence'] = script_dataframe['Sentence'].apply(lambda x: str(x).replace('’', '\''))
script_dataframe['Sentence'] = script_dataframe['Sentence'].apply(lambda x: str(x).replace('d\'', 'do '))
script_dataframe.head()
# Out:
#   Release Date    Season    Episode     Episode Title          Name  \
# 0   2011-04-17  Season 1  Episode 1  Winter is Coming  waymar royce
# 1   2011-04-17  Season 1  Episode 1  Winter is Coming          will
# 2   2011-04-17  Season 1  Episode 1  Winter is Coming  waymar royce
# 3   2011-04-17  Season 1  Episode 1  Winter is Coming          will
# 4   2011-04-17  Season 1  Episode 1  Winter is Coming         gared
#
#                                             Sentence
# 0  What do you expect? They're savages. One lot s...
# 1  I've never seen wildlings do a thing like this...
# 2                             How close did you get?
# 3                            Close as any man would.
# 4                   We should head back to the wall.

# %%
script_dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 24390 entries, 0 to 25713
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Release Date   24390 non-null  object
#  1   Season         24390 non-null  object
#  2   Episode        24390 non-null  object
#  3   Episode Title  24390 non-null  object
#  4   Name           24390 non-null  object
#  5   Sentence       24390 non-null  object
# dtypes: object(6)
# memory usage: 1.3+ MB

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', -1)
# Out:
# /home/maxisses/TechnologyStuff/nlp/lib/python3.6/site-packages/ipykernel_launcher.py:4: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.
#   after removing the cwd from sys.path.

# %%
script_dataframe[script_dataframe["Name"] == "changeofscene"]
# Out:
#       Release Date    Season     Episode                   Episode Title  \
# 15     2011-04-17   Season 1  Episode 1   Winter is Coming
# 16     2011-04-17   Season 1  Episode 1   Winter is Coming
# 19     2011-04-17   Season 1  Episode 1   Winter is Coming
# 36     2011-04-17   Season 1  Episode 1   Winter is Coming
# 56     2011-04-17   Season 1  Episode 1   Winter is Coming
# 81     2011-04-17   Season 1  Episode 1   Winter is Coming
# 91     2011-04-17   Season 1  Episode 1   Winter is Coming
# 103    2011-04-17   Season 1  Episode 1   Winter is Coming
# 109    2011-04-17   Season 1  Episode 1   Winter is Coming
# 115    2011-04-17   Season 1  Episode 1   Winter is Coming
# 125    2011-04-17   Season 1  Episode 1   Winter is Coming
# 149    2011-04-17   Season 1  Episode 1   Winter is Coming
# 158    2011-04-17   Season 1  Episode 1   Winter is Coming
# 182    2011-04-17   Season 1  Episode 1   Winter is Coming
# 189    2011-04-17   Season 1  Episode 1   Winter is Coming
# 197    2011-04-17   Season 1  Episode 1   Winter is Coming
# 207    2011-04-17   Season 1  Episode 1   Winter is Coming
# 220    2011-04-17   Season 1  Episode 1   Winter is Coming
# 231    2011-04-17   Season 1  Episode 1   Winter is Coming
# 255    2011-04-17   Season 1  Episode 1   Winter is Coming
# 291    2011-04-17   Season 1  Episode 1   Winter is Coming
# 312    2011-04-17   Season 1  Episode 1   Winter is Coming
# 327    2011-04-17   Season 1  Episode 1   Winter is Coming
# 333    2011-04-17   Season 1  Episode 1   Winter is Coming
# 3232   2012-04-01   Season 2  Episode 1   The North Remembers
# 3273   2012-04-01   Season 2  Episode 1   The North Remembers
# 3313   2012-04-01   Season 2  Episode 1   The North Remembers
# 3314   2012-04-01   Season 2  Episode 1   The North Remembers
# 3316   2012-04-01   Season 2  Episode 1   The North Remembers
# 3330   2012-04-01   Season 2  Episode 1   The North Remembers
# 3331   2012-04-01   Season 2  Episode 1   The North Remembers
# 3332   2012-04-01   Season 2  Episode 1   The North Remembers
# 3345   2012-04-01   Season 2  Episode 1   The North Remembers
# 3389   2012-04-01   Season 2  Episode 1   The North Remembers
# 3423   2012-04-01   Season 2  Episode 1   The North Remembers
# 3432   2012-04-01   Season 2  Episode 1   The North Remembers
# 3453   2012-04-01   Season 2  Episode 1   The North Remembers
# 3477   2012-04-01   Season 2  Episode 1   The North Remembers
# 3496   2012-04-01   Season 2  Episode 1   The North Remembers
# 3516   2012-04-01   Season 2  Episode 1   The North Remembers
# 3537   2012-04-01   Season 2  Episode 1   The North Remembers
# 3559   2012-04-01   Season 2  Episode 1   The North Remembers
# 3584   2012-04-01   Season 2  Episode 1   The North Remembers
# 3602   2012-04-01   Season 2  Episode 1   The North Remembers
# 3621   2012-04-01   Season 2  Episode 1   The North Remembers
# 3623   2012-04-01   Season 2  Episode 1   The North Remembers
# 3625   2012-04-01   Season 2  Episode 1   The North Remembers
# 3626   2012-04-01   Season 2  Episode 1   The North Remembers
# 3636   2012-04-01   Season 2  Episode 1   The North Remembers
# 3638   2012-04-08   Season 2  Episode 2   The Night Lands
# 3644   2012-04-08   Season 2  Episode 2   The Night Lands
# 3648   2012-04-08   Season 2  Episode 2   The Night Lands
# 3653   2012-04-08   Season 2  Episode 2   The Night Lands
# 3656   2012-04-08   Season 2  Episode 2   The Night Lands
# 3665   2012-04-08   Season 2  Episode 2   The Night Lands
# 3668   2012-04-08   Season 2  Episode 2   The Night Lands
# 3670   2012-04-08   Season 2  Episode 2   The Night Lands
# 3703   2012-04-08   Season 2  Episode 2   The Night Lands
# 3704   2012-04-08   Season 2  Episode 2   The Night Lands
# 3754   2012-04-08   Season 2  Episode 2   The Night Lands
# 3812   2012-04-08   Season 2  Episode 2   The Night Lands
# 3844   2012-04-08   Season 2  Episode 2   The Night Lands
# 3891   2012-04-08   Season 2  Episode 2   The Night Lands
# 3948   2012-04-08   Season 2  Episode 2   The Night Lands
# 3962   2012-04-08   Season 2  Episode 2   The Night Lands
# 3971   2012-04-08   Season 2  Episode 2   The Night Lands
# 4055   2012-04-08   Season 2  Episode 2   The Night Lands
# 4071   2012-04-08   Season 2  Episode 2   The Night Lands
# 4104   2012-04-08   Season 2  Episode 2   The Night Lands
# 4105   2012-04-15   Season 2  Episode 3   What Is Dead May Never Die
# 4413   2012-04-15   Season 2  Episode 3   What Is Dead May Never Die
# 4436   2012-04-22   Season 2  Episode 4   Garden of Bones
# 4459   2012-04-22   Season 2  Episode 4   Garden of Bones
# 4486   2012-04-22   Season 2  Episode 4   Garden of Bones
# 4512   2012-04-22   Season 2  Episode 4   Garden of Bones
# 4513   2012-04-22   Season 2  Episode 4   Garden of Bones
# 4546   2012-04-22   Season 2  Episode 4   Garden of Bones
# 4593   2012-04-22   Season 2  Episode 4   Garden of Bones
# 4602   2012-04-22   Season 2  Episode 4   Garden of Bones
# 4613   2012-04-22   Season 2  Episode 4   Garden of Bones
# 4620   2012-04-22   Season 2  Episode 4   Garden of Bones
# 4650   2012-04-22   Season 2  Episode 4   Garden of Bones
# 4674   2012-04-22   Season 2  Episode 4   Garden of Bones
# 4678   2012-04-22   Season 2  Episode 4   Garden of Bones
# 4705   2012-04-22   Season 2  Episode 4   Garden of Bones
# 4763   2012-04-22   Season 2  Episode 4   Garden of Bones
# 4764   2012-04-22   Season 2  Episode 4   Garden of Bones
# 4801   2012-04-22   Season 2  Episode 4   Garden of Bones
# 4820   2012-04-22   Season 2  Episode 4   Garden of Bones
# 4835   2012-04-22   Season 2  Episode 4   Garden of Bones
# 4842   2012-04-29   Season 2  Episode 5   The Ghost of Harrenhal
# 4843   2012-04-29   Season 2  Episode 5   The Ghost of Harrenhal
# 4890   2012-04-29   Season 2  Episode 5   The Ghost of Harrenhal
# 4891   2012-04-29   Season 2  Episode 5   The Ghost of Harrenhal
# 4911   2012-04-29   Season 2  Episode 5   The Ghost of Harrenhal
# 4935   2012-04-29   Season 2  Episode 5   The Ghost of Harrenhal
# 4965   2012-04-29   Season 2  Episode 5   The Ghost of Harrenhal
# 5017   2012-04-29   Season 2  Episode 5   The Ghost of Harrenhal
# 5043   2012-04-29   Season 2  Episode 5   The Ghost of Harrenhal
# 5074   2012-04-29   Season 2  Episode 5   The Ghost of Harrenhal
# 5127   2012-04-29   Season 2  Episode 5   The Ghost of Harrenhal
# 5179   2012-04-29   Season 2  Episode 5   The Ghost of Harrenhal
# 5237   2012-04-29   Season 2  Episode 5   The Ghost of Harrenhal
# 5255   2012-04-29   Season 2  Episode 5   The Ghost of Harrenhal
# 5266   2012-04-29   Season 2  Episode 5   The Ghost of Harrenhal
# 5488   2012-05-06   Season 2  Episode 6   The Old Gods and the New
# 6109   2012-05-13   Season 2  Episode 7   A Man Without Honor
# 6323   2012-05-20   Season 2  Episode 8   The Prince of Winterfell
# 6623   2012-05-27   Season 2  Episode 9   Blackwater
# 6757   2012-05-27   Season 2  Episode 9   Blackwater
# 7046   2012-06-03   Season 2  Episode 10  Valar Morghulis
# 7465   2013-03-31   Season 3  Episode 1   Valar Dohaeris
# 7466   2013-03-31   Season 3  Episode 1   Valar Dohaeris
# 7479   2013-03-31   Season 3  Episode 1   Valar Dohaeris
# 7515   2013-03-31   Season 3  Episode 1   Valar Dohaeris
# 7543   2013-03-31   Season 3  Episode 1   Valar Dohaeris
# 7545   2013-03-31   Season 3  Episode 1   Valar Dohaeris
# 7550   2013-03-31   Season 3  Episode 1   Valar Dohaeris
# 7579   2013-03-31   Season 3  Episode 1   Valar Dohaeris
# 7584   2013-03-31   Season 3  Episode 1   Valar Dohaeris
# 7600   2013-03-31   Season 3  Episode 1   Valar Dohaeris
# 7622   2013-03-31   Season 3  Episode 1   Valar Dohaeris
# 7657   2013-03-31   Season 3  Episode 1   Valar Dohaeris
# 7667   2013-03-31   Season 3  Episode 1   Valar Dohaeris
# 7668   2013-03-31   Season 3  Episode 1   Valar Dohaeris
# 7693   2013-03-31   Season 3  Episode 1   Valar Dohaeris
# 7719   2013-03-31   Season 3  Episode 1   Valar Dohaeris
# 7741   2013-03-31   Season 3  Episode 1   Valar Dohaeris
# 8003   2013-04-07   Season 3  Episode 2   Dark Wings, Dark Words
# 8437   2013-04-14   Season 3  Episode 3   Walk of Punishment
# 8452   2013-04-14   Season 3  Episode 3   Walk of Punishment
# 8474   2013-04-14   Season 3  Episode 3   Walk of Punishment
# 8601   2013-04-14   Season 3  Episode 3   Walk of Punishment
# 8650   2013-04-14   Season 3  Episode 3   Walk of Punishment
# 8697   2013-04-21   Season 3  Episode 4   And Now His Watch Is Ended
# 8767   2013-04-21   Season 3  Episode 4   And Now His Watch Is Ended
# 9103   2013-04-28   Season 3  Episode 5   Kissed by Fire
# 9422   2013-05-05   Season 3  Episode 6   The Climb
# 9685   2013-05-12   Season 3  Episode 7   The Bear and the Maiden Fair
# 10098  2013-05-19   Season 3  Episode 8   Second Sons
# 10734  2013-06-09   Season 3  Episode 10  Mhysa
# 11159  2014-04-06   Season 4  Episode 1   Two Swords
# 11160  2014-04-06   Season 4  Episode 1   Two Swords
# 11202  2014-04-06   Season 4  Episode 1   Two Swords
# 11233  2014-04-06   Season 4  Episode 1   Two Swords
# 11296  2014-04-06   Season 4  Episode 1   Two Swords
# 11315  2014-04-06   Season 4  Episode 1   Two Swords
# 11335  2014-04-06   Season 4  Episode 1   Two Swords
# 11359  2014-04-06   Season 4  Episode 1   Two Swords
# 11387  2014-04-06   Season 4  Episode 1   Two Swords
# 11438  2014-04-06   Season 4  Episode 1   Two Swords
# 11466  2014-04-06   Season 4  Episode 1   Two Swords
# 11477  2014-04-06   Season 4  Episode 1   Two Swords
# 11510  2014-04-06   Season 4  Episode 1   Two Swords
# 11574  2014-04-06   Season 4  Episode 1   Two Swords
# 11597  2014-04-06   Season 4  Episode 1   Two Swords
# 11672  2014-04-06   Season 4  Episode 1   Two Swords
# 11744  2014-04-13   Season 4  Episode 2   The Lion and the Rose
# 12077  2014-04-20   Season 4  Episode 3   Breaker of Chains
# 12085  2014-04-20   Season 4  Episode 3   Breaker of Chains
# 12089  2014-04-20   Season 4  Episode 3   Breaker of Chains
# 12091  2014-04-20   Season 4  Episode 3   Breaker of Chains
# 12113  2014-04-20   Season 4  Episode 3   Breaker of Chains
# 12219  2014-04-20   Season 4  Episode 3   Breaker of Chains
# 12235  2014-04-20   Season 4  Episode 3   Breaker of Chains
# 12266  2014-04-20   Season 4  Episode 3   Breaker of Chains
# 12313  2014-04-20   Season 4  Episode 3   Breaker of Chains
# 12331  2014-04-20   Season 4  Episode 3   Breaker of Chains
# 12338  2014-04-20   Season 4  Episode 3   Breaker of Chains
# 12400  2014-04-20   Season 4  Episode 3   Breaker of Chains
# 12460  2014-04-20   Season 4  Episode 3   Breaker of Chains
# 12472  2014-04-20   Season 4  Episode 3   Breaker of Chains
# 12515  2014-04-27   Season 4  Episode 4   Oathkeeper
# 12533  2014-04-27   Season 4  Episode 4   Oathkeeper
# 12534  2014-04-27   Season 4  Episode 4   Oathkeeper
# 12548  2014-04-27   Season 4  Episode 4   Oathkeeper
# 12549  2014-04-27   Season 4  Episode 4   Oathkeeper
# 12560  2014-04-27   Season 4  Episode 4   Oathkeeper
# 12574  2014-04-27   Season 4  Episode 4   Oathkeeper
# 12599  2014-04-27   Season 4  Episode 4   Oathkeeper
# 12622  2014-04-27   Season 4  Episode 4   Oathkeeper
# 12641  2014-04-27   Season 4  Episode 4   Oathkeeper
# 12672  2014-04-27   Season 4  Episode 4   Oathkeeper
# 12693  2014-04-27   Season 4  Episode 4   Oathkeeper
# 12713  2014-04-27   Season 4  Episode 4   Oathkeeper
# 12723  2014-04-27   Season 4  Episode 4   Oathkeeper
# 12736  2014-04-27   Season 4  Episode 4   Oathkeeper
# 12751  2014-04-27   Season 4  Episode 4   Oathkeeper
# 12760  2014-04-27   Season 4  Episode 4   Oathkeeper
# 12785  2014-04-27   Season 4  Episode 4   Oathkeeper
# 12803  2014-04-27   Season 4  Episode 4   Oathkeeper
# 12835  2014-04-27   Season 4  Episode 4   Oathkeeper
# 12836  2014-05-04   Season 4  Episode 5   First of His Name
# 12840  2014-05-04   Season 4  Episode 5   First of His Name
# 12868  2014-05-04   Season 4  Episode 5   First of His Name
# 12897  2014-05-04   Season 4  Episode 5   First of His Name
# 12957  2014-05-04   Season 4  Episode 5   First of His Name
# 12996  2014-05-04   Season 4  Episode 5   First of His Name
# 13008  2014-05-04   Season 4  Episode 5   First of His Name
# 13041  2014-05-04   Season 4  Episode 5   First of His Name
# 13056  2014-05-04   Season 4  Episode 5   First of His Name
# 13081  2014-05-04   Season 4  Episode 5   First of His Name
# 13137  2014-05-04   Season 4  Episode 5   First of His Name
# 13204  2014-05-04   Season 4  Episode 5   First of His Name
# 13205  2014-05-04   Season 4  Episode 5   First of His Name
# 13318  2014-05-11   Season 4  Episode 6   The Laws of Gods and Men
# 13584  2014-05-18   Season 4  Episode 7   Mockingbird
# 13604  2014-05-18   Season 4  Episode 7   Mockingbird
# 13613  2014-05-18   Season 4  Episode 7   Mockingbird
# 13649  2014-05-18   Season 4  Episode 7   Mockingbird
# 13660  2014-05-18   Season 4  Episode 7   Mockingbird
# 13685  2014-05-18   Season 4  Episode 7   Mockingbird
# 13728  2014-05-18   Season 4  Episode 7   Mockingbird
# 13749  2014-05-18   Season 4  Episode 7   Mockingbird
# 13773  2014-05-18   Season 4  Episode 7   Mockingbird
# 13775  2014-05-18   Season 4  Episode 7   Mockingbird
# 13806  2014-05-18   Season 4  Episode 7   Mockingbird
# 13818  2014-05-18   Season 4  Episode 7   Mockingbird
# 13838  2014-05-18   Season 4  Episode 7   Mockingbird
# 13859  2014-05-18   Season 4  Episode 7   Mockingbird
# 13868  2014-05-18   Season 4  Episode 7   Mockingbird
# 13890  2014-05-18   Season 4  Episode 7   Mockingbird
# 13934  2014-05-18   Season 4  Episode 7   Mockingbird
# 13969  2014-06-01   Season 4  Episode 8   The Mountain and the Viper
# 14549  2014-06-15   Season 4  Episode 10  The Children
# 14821  2015-04-12   Season 5  Episode 1   The Wars to Come
# 14832  2015-04-12   Season 5  Episode 1   The Wars to Come
# 14853  2015-04-12   Season 5  Episode 1   The Wars to Come
# 14859  2015-04-12   Season 5  Episode 1   The Wars to Come
# 14868  2015-04-12   Season 5  Episode 1   The Wars to Come
# 14884  2015-04-12   Season 5  Episode 1   The Wars to Come
# 14888  2015-04-12   Season 5  Episode 1   The Wars to Come
# 14901  2015-04-12   Season 5  Episode 1   The Wars to Come
# 14927  2015-04-12   Season 5  Episode 1   The Wars to Come
# 14934  2015-04-12   Season 5  Episode 1   The Wars to Come
# 14990  2015-04-12   Season 5  Episode 1   The Wars to Come
# 15083  2015-04-12   Season 5  Episode 1   The Wars to Come
# 15101  2015-04-12   Season 5  Episode 1   The Wars to Come
# 15115  2015-04-12   Season 5  Episode 1   The Wars to Come
# 15119  2015-04-12   Season 5  Episode 1   The Wars to Come
# 15143  2015-04-12   Season 5  Episode 1   The Wars to Come
# 15153  2015-04-19   Season 5  Episode 2   The House of Black and White
# 15155  2015-04-19   Season 5  Episode 2   The House of Black and White
# 15166  2015-04-19   Season 5  Episode 2   The House of Black and White
# 15168  2015-04-19   Season 5  Episode 2   The House of Black and White
# 15170  2015-04-19   Season 5  Episode 2   The House of Black and White
# 15172  2015-04-19   Season 5  Episode 2   The House of Black and White
# 15225  2015-04-19   Season 5  Episode 2   The House of Black and White
# 15241  2015-04-19   Season 5  Episode 2   The House of Black and White
# 15267  2015-04-19   Season 5  Episode 2   The House of Black and White
# 15304  2015-04-19   Season 5  Episode 2   The House of Black and White
# 15323  2015-04-19   Season 5  Episode 2   The House of Black and White
# 15332  2015-04-19   Season 5  Episode 2   The House of Black and White
# 15363  2015-04-19   Season 5  Episode 2   The House of Black and White
# 15391  2015-04-19   Season 5  Episode 2   The House of Black and White
# 15401  2015-04-19   Season 5  Episode 2   The House of Black and White
# 15426  2015-04-19   Season 5  Episode 2   The House of Black and White
# 15458  2015-04-19   Season 5  Episode 2   The House of Black and White
# 15479  2015-04-19   Season 5  Episode 2   The House of Black and White
# 15507  2015-04-19   Season 5  Episode 2   The House of Black and White
# 15522  2015-04-19   Season 5  Episode 2   The House of Black and White
# 15524  2015-04-19   Season 5  Episode 2   The House of Black and White
# 15525  2015-04-19   Season 5  Episode 2   The House of Black and White
# 15535  2015-04-19   Season 5  Episode 2   The House of Black and White
# 15546  2015-04-19   Season 5  Episode 2   The House of Black and White
# 15552  2015-04-26   Season 5  Episode 3   High Sparrow
# 15553  2015-04-26   Season 5  Episode 3   High Sparrow
# 15568  2015-04-26   Season 5  Episode 3   High Sparrow
# 15570  2015-04-26   Season 5  Episode 3   High Sparrow
# 15572  2015-04-26   Season 5  Episode 3   High Sparrow
# 15600  2015-04-26   Season 5  Episode 3   High Sparrow
# 15611  2015-04-26   Season 5  Episode 3   High Sparrow
# 15630  2015-04-26   Season 5  Episode 3   High Sparrow
# 15631  2015-04-26   Season 5  Episode 3   High Sparrow
# 15645  2015-04-26   Season 5  Episode 3   High Sparrow
# 15670  2015-04-26   Season 5  Episode 3   High Sparrow
# 15700  2015-04-26   Season 5  Episode 3   High Sparrow
# 15739  2015-04-26   Season 5  Episode 3   High Sparrow
# 15757  2015-04-26   Season 5  Episode 3   High Sparrow
# 15767  2015-04-26   Season 5  Episode 3   High Sparrow
# 15793  2015-04-26   Season 5  Episode 3   High Sparrow
# 15811  2015-04-26   Season 5  Episode 3   High Sparrow
# 15847  2015-04-26   Season 5  Episode 3   High Sparrow
# 15883  2015-04-26   Season 5  Episode 3   High Sparrow
# 15943  2015-04-26   Season 5  Episode 3   High Sparrow
# 15948  2015-05-03   Season 5  Episode 4   Sons of the Harpy
# 15949  2015-05-03   Season 5  Episode 4   Sons of the Harpy
# 15952  2015-05-03   Season 5  Episode 4   Sons of the Harpy
# 15975  2015-05-03   Season 5  Episode 4   Sons of the Harpy
# 15993  2015-05-03   Season 5  Episode 4   Sons of the Harpy
# 16012  2015-05-03   Season 5  Episode 4   Sons of the Harpy
# 16013  2015-05-03   Season 5  Episode 4   Sons of the Harpy
# 16014  2015-05-03   Season 5  Episode 4   Sons of the Harpy
# 16017  2015-05-03   Season 5  Episode 4   Sons of the Harpy
# 16023  2015-05-03   Season 5  Episode 4   Sons of the Harpy
# 16029  2015-05-03   Season 5  Episode 4   Sons of the Harpy
# 16041  2015-05-03   Season 5  Episode 4   Sons of the Harpy
# 16048  2015-05-03   Season 5  Episode 4   Sons of the Harpy
# 16060  2015-05-03   Season 5  Episode 4   Sons of the Harpy
# 16074  2015-05-03   Season 5  Episode 4   Sons of the Harpy
# 16093  2015-05-03   Season 5  Episode 4   Sons of the Harpy
# 16121  2015-05-03   Season 5  Episode 4   Sons of the Harpy
# 16134  2015-05-03   Season 5  Episode 4   Sons of the Harpy
# 16166  2015-05-03   Season 5  Episode 4   Sons of the Harpy
# 16167  2015-05-03   Season 5  Episode 4   Sons of the Harpy
# 16249  2015-05-03   Season 5  Episode 4   Sons of the Harpy
# 16271  2015-05-03   Season 5  Episode 4   Sons of the Harpy
# 16282  2015-05-10   Season 5  Episode 5   Kill the Boy
# 16283  2015-05-10   Season 5  Episode 5   Kill the Boy
# 16290  2015-05-10   Season 5  Episode 5   Kill the Boy
# 16299  2015-05-10   Season 5  Episode 5   Kill the Boy
# 16300  2015-05-10   Season 5  Episode 5   Kill the Boy
# 16341  2015-05-10   Season 5  Episode 5   Kill the Boy
# 16354  2015-05-10   Season 5  Episode 5   Kill the Boy
# 16363  2015-05-10   Season 5  Episode 5   Kill the Boy
# 16379  2015-05-10   Season 5  Episode 5   Kill the Boy
# 16391  2015-05-10   Season 5  Episode 5   Kill the Boy
# 16397  2015-05-10   Season 5  Episode 5   Kill the Boy
# 16409  2015-05-10   Season 5  Episode 5   Kill the Boy
# 16458  2015-05-10   Season 5  Episode 5   Kill the Boy
# 16519  2015-05-10   Season 5  Episode 5   Kill the Boy
# 16534  2015-05-10   Season 5  Episode 5   Kill the Boy
# 16544  2015-05-10   Season 5  Episode 5   Kill the Boy
# 16550  2015-05-10   Season 5  Episode 5   Kill the Boy
# 16558  2015-05-10   Season 5  Episode 5   Kill the Boy
# 16573  2015-05-10   Season 5  Episode 5   Kill the Boy
# 16585  2015-05-10   Season 5  Episode 5   Kill the Boy
# 16595  2015-05-17   Season 5  Episode 6   Unbowed, Unbent, Unbroken
# 16616  2015-05-17   Season 5  Episode 6   Unbowed, Unbent, Unbroken
# 16635  2015-05-17   Season 5  Episode 6   Unbowed, Unbent, Unbroken
# 16658  2015-05-17   Season 5  Episode 6   Unbowed, Unbent, Unbroken
# 16665  2015-05-17   Season 5  Episode 6   Unbowed, Unbent, Unbroken
# 16666  2015-05-17   Season 5  Episode 6   Unbowed, Unbent, Unbroken
# 16669  2015-05-17   Season 5  Episode 6   Unbowed, Unbent, Unbroken
# 16716  2015-05-17   Season 5  Episode 6   Unbowed, Unbent, Unbroken
# 16726  2015-05-17   Season 5  Episode 6   Unbowed, Unbent, Unbroken
# 16766  2015-05-17   Season 5  Episode 6   Unbowed, Unbent, Unbroken
# 16782  2015-05-17   Season 5  Episode 6   Unbowed, Unbent, Unbroken
# 16793  2015-05-17   Season 5  Episode 6   Unbowed, Unbent, Unbroken
# 16794  2015-05-17   Season 5  Episode 6   Unbowed, Unbent, Unbroken
# 16797  2015-05-17   Season 5  Episode 6   Unbowed, Unbent, Unbroken
# 16822  2015-05-17   Season 5  Episode 6   Unbowed, Unbent, Unbroken
# 16825  2015-05-17   Season 5  Episode 6   Unbowed, Unbent, Unbroken
# 16852  2015-05-17   Season 5  Episode 6   Unbowed, Unbent, Unbroken
# 16901  2015-05-17   Season 5  Episode 6   Unbowed, Unbent, Unbroken
# 16916  2015-05-17   Season 5  Episode 6   Unbowed, Unbent, Unbroken
# 16918  2015-05-17   Season 5  Episode 6   Unbowed, Unbent, Unbroken
# 16925  2015-05-17   Season 5  Episode 6   Unbowed, Unbent, Unbroken
# 16932  2015-05-17   Season 5  Episode 6   Unbowed, Unbent, Unbroken
# 16947  2015-05-24   Season 5  Episode 7   The Gift
# 16956  2015-05-24   Season 5  Episode 7   The Gift
# 16961  2015-05-24   Season 5  Episode 7   The Gift
# 16962  2015-05-24   Season 5  Episode 7   The Gift
# 16980  2015-05-24   Season 5  Episode 7   The Gift
# 16981  2015-05-24   Season 5  Episode 7   The Gift
# 16983  2015-05-24   Season 5  Episode 7   The Gift
# 16984  2015-05-24   Season 5  Episode 7   The Gift
# 17014  2015-05-24   Season 5  Episode 7   The Gift
# 17015  2015-05-24   Season 5  Episode 7   The Gift
# 17047  2015-05-24   Season 5  Episode 7   The Gift
# 17079  2015-05-24   Season 5  Episode 7   The Gift
# 17093  2015-05-24   Season 5  Episode 7   The Gift
# 17108  2015-05-24   Season 5  Episode 7   The Gift
# 17130  2015-05-24   Season 5  Episode 7   The Gift
# 17158  2015-05-24   Season 5  Episode 7   The Gift
# 17160  2015-05-24   Season 5  Episode 7   The Gift
# 17173  2015-05-24   Season 5  Episode 7   The Gift
# 17186  2015-05-24   Season 5  Episode 7   The Gift
# 17219  2015-05-24   Season 5  Episode 7   The Gift
# 17235  2015-05-24   Season 5  Episode 7   The Gift
# 17241  2015-05-24   Season 5  Episode 7   The Gift
# 17248  2015-05-24   Season 5  Episode 7   The Gift
# 17265  2015-05-24   Season 5  Episode 7   The Gift
# 17277  2015-05-24   Season 5  Episode 7   The Gift
# 17302  2015-05-24   Season 5  Episode 7   The Gift
# 17305  2015-05-31   Season 5  Episode 8   Hardhome
# 17331  2015-05-31   Season 5  Episode 8   Hardhome
# 17336  2015-05-31   Season 5  Episode 8   Hardhome
# 17338  2015-05-31   Season 5  Episode 8   Hardhome
# 17390  2015-05-31   Season 5  Episode 8   Hardhome
# 17412  2015-05-31   Season 5  Episode 8   Hardhome
# 17421  2015-05-31   Season 5  Episode 8   Hardhome
# 17469  2015-05-31   Season 5  Episode 8   Hardhome
# 17482  2015-05-31   Season 5  Episode 8   Hardhome
# 17518  2015-05-31   Season 5  Episode 8   Hardhome
# 17538  2015-05-31   Season 5  Episode 8   Hardhome
# 17587  2015-05-31   Season 5  Episode 8   Hardhome
# 17622  2015-06-07   Season 5  Episode 9   The Dance of Dragons
# 17623  2015-06-07   Season 5  Episode 9   The Dance of Dragons
# 17625  2015-06-07   Season 5  Episode 9   The Dance of Dragons
# 17636  2015-06-07   Season 5  Episode 9   The Dance of Dragons
# 17638  2015-06-07   Season 5  Episode 9   The Dance of Dragons
# 17645  2015-06-07   Season 5  Episode 9   The Dance of Dragons
# 17658  2015-06-07   Season 5  Episode 9   The Dance of Dragons
# 17659  2015-06-07   Season 5  Episode 9   The Dance of Dragons
# 17676  2015-06-07   Season 5  Episode 9   The Dance of Dragons
# 17712  2015-06-07   Season 5  Episode 9   The Dance of Dragons
# 17736  2015-06-07   Season 5  Episode 9   The Dance of Dragons
# 17747  2015-06-07   Season 5  Episode 9   The Dance of Dragons
# 17755  2015-06-07   Season 5  Episode 9   The Dance of Dragons
# 17760  2015-06-07   Season 5  Episode 9   The Dance of Dragons
# 17767  2015-06-07   Season 5  Episode 9   The Dance of Dragons
# 17773  2015-06-07   Season 5  Episode 9   The Dance of Dragons
# 17790  2015-06-07   Season 5  Episode 9   The Dance of Dragons
# 17801  2015-06-07   Season 5  Episode 9   The Dance of Dragons
# 17846  2015-06-07   Season 5  Episode 9   The Dance of Dragons
# 17897  2015-06-14   Season 5  Episode 10  Mother’s Mercy
# 17898  2015-06-14   Season 5  Episode 10  Mother’s Mercy
# 17899  2015-06-14   Season 5  Episode 10  Mother’s Mercy
# 17903  2015-06-14   Season 5  Episode 10  Mother’s Mercy
# 17913  2015-06-14   Season 5  Episode 10  Mother’s Mercy
# 17917  2015-06-14   Season 5  Episode 10  Mother’s Mercy
# 17947  2015-06-14   Season 5  Episode 10  Mother’s Mercy
# 17948  2015-06-14   Season 5  Episode 10  Mother’s Mercy
# 17949  2015-06-14   Season 5  Episode 10  Mother’s Mercy
# 17950  2015-06-14   Season 5  Episode 10  Mother’s Mercy
# 17952  2015-06-14   Season 5  Episode 10  Mother’s Mercy
# 17956  2015-06-14   Season 5  Episode 10  Mother’s Mercy
# 17964  2015-06-14   Season 5  Episode 10  Mother’s Mercy
# 17970  2015-06-14   Season 5  Episode 10  Mother’s Mercy
# 17976  2015-06-14   Season 5  Episode 10  Mother’s Mercy
# 17985  2015-06-14   Season 5  Episode 10  Mother’s Mercy
# 17992  2015-06-14   Season 5  Episode 10  Mother’s Mercy
# 18012  2015-06-14   Season 5  Episode 10  Mother’s Mercy
# 18021  2015-06-14   Season 5  Episode 10  Mother’s Mercy
# 18041  2015-06-14   Season 5  Episode 10  Mother’s Mercy
# 18088  2015-06-14   Season 5  Episode 10  Mother’s Mercy
# 18099  2015-06-14   Season 5  Episode 10  Mother’s Mercy
# 18105  2015-06-14   Season 5  Episode 10  Mother’s Mercy
# 18107  2015-06-14   Season 5  Episode 10  Mother’s Mercy
# 18142  2015-06-14   Season 5  Episode 10  Mother’s Mercy
# 18148  2015-06-14   Season 5  Episode 10  Mother’s Mercy
# 18161  2015-06-14   Season 5  Episode 10  Mother’s Mercy
# 18179  2015-04-24   Season 6  Episode 1   The Red Woman
# 18415  2016-05-01   Season 6  Episode 2   Home
# 18416  2016-05-01   Season 6  Episode 2   Home
# 18565  2016-05-01   Season 6  Episode 2   Home
# 18581  2016-05-01   Season 6  Episode 2   Home
# 18625  2016-05-01   Season 6  Episode 2   Home
# 18649  2016-05-01   Season 6  Episode 2   Home
# 18729  2016-05-08   Season 6  Episode 3   Oathbreaker
# 18864  2016-05-08   Season 6  Episode 3   Oathbreaker
# 18933  2016-05-08   Season 6  Episode 3   Oathbreaker
# 18964  2016-05-08   Season 6  Episode 3   Oathbreaker
# 18997  2016-05-08   Season 6  Episode 3   Oathbreaker
# 19013  2016-05-15   Season 6  Episode 4   Book of the Stranger
# 19026  2016-05-15   Season 6  Episode 4   Book of the Stranger
# 19174  2016-05-15   Season 6  Episode 4   Book of the Stranger
# 19344  2016-05-15   Season 6  Episode 4   Book of the Stranger
# 19371  2016-05-15   Season 6  Episode 4   Book of the Stranger
# 19398  2016-05-15   Season 6  Episode 4   Book of the Stranger
# 19429  2016-05-22   Season 6  Episode 5   The Door
# 19433  2016-05-22   Season 6  Episode 5   The Door
# 19798  2016-05-29   Season 6  Episode 6   Blood of My Blood
# 20088  2016-06-05   Season 6  Episode 7   The Broken Man
# 20378  2016-06-12   Season 6  Episode 8   No One
# 20756  2016-06-19   Season 6  Episode 9   Battle of the Bastards
# 20945  2016-06-26   Season 6  Episode 10  The Winds of Winter
# 21086  2016-06-26   Season 6  Episode 10  The Winds of Winter
# 21284  2017-07-16   Season 7  Episode 1   Dragonstone
# 21636  2017-07-23   Season 7  Episode 2   Stormborn
# 21755  2017-07-23   Season 7  Episode 2   Stormborn
# 21775  2017-07-23   Season 7  Episode 2   Stormborn
# 21949  2017-07-30   Season 7  Episode 3   The Queen’s Justice
# 22363  2017-08-06   Season 7  Episode 4   The Spoils Of War
# 22448  2017-08-06   Season 7  Episode 4   The Spoils Of War
# 22762  2017-08-13   Season 7  Episode 5   Eastwatch
# 23280  2017-08-20   Season 7  Episode 6   Beyond the Wall
# 23281  2017-08-20   Season 7  Episode 6   Beyond the Wall
# 23465  2017-08-27   Season 7  Episode 7   The Dragon and the Wolf
# 23485  2017-08-27   Season 7  Episode 7   The Dragon and the Wolf
# 23490  2017-08-27   Season 7  Episode 7   The Dragon and the Wolf
# 23491  2017-08-27   Season 7  Episode 7   The Dragon and the Wolf
# 23887  2019-04-14   Season 8  Episode 1   Winterfell
# 24214  2019-04-21   Season 8  Episode 2   A Knight of the Seven Kingdoms
# 24666  2019-04-28   Season 8  Episode 3   The Long Night
# 25002  2019-05-05   Season 8  Episode 4   The Last of the Starks
# 25039  2019-05-12   Season 8  Episode 5   The Bells
# 25458  2019-05-19   Season 8  Episode 6   The Iron Throne
#
#                 Name  \
# 15     changeofscene
# 16     changeofscene
# 19     changeofscene
# 36     changeofscene
# 56     changeofscene
# 81     changeofscene
# 91     changeofscene
# 103    changeofscene
# 109    changeofscene
# 115    changeofscene
# 125    changeofscene
# 149    changeofscene
# 158    changeofscene
# 182    changeofscene
# 189    changeofscene
# 197    changeofscene
# 207    changeofscene
# 220    changeofscene
# 231    changeofscene
# 255    changeofscene
# 291    changeofscene
# 312    changeofscene
# 327    changeofscene
# 333    changeofscene
# 3232   changeofscene
# 3273   changeofscene
# 3313   changeofscene
# 3314   changeofscene
# 3316   changeofscene
# 3330   changeofscene
# 3331   changeofscene
# 3332   changeofscene
# 3345   changeofscene
# 3389   changeofscene
# 3423   changeofscene
# 3432   changeofscene
# 3453   changeofscene
# 3477   changeofscene
# 3496   changeofscene
# 3516   changeofscene
# 3537   changeofscene
# 3559   changeofscene
# 3584   changeofscene
# 3602   changeofscene
# 3621   changeofscene
# 3623   changeofscene
# 3625   changeofscene
# 3626   changeofscene
# 3636   changeofscene
# 3638   changeofscene
# 3644   changeofscene
# 3648   changeofscene
# 3653   changeofscene
# 3656   changeofscene
# 3665   changeofscene
# 3668   changeofscene
# 3670   changeofscene
# 3703   changeofscene
# 3704   changeofscene
# 3754   changeofscene
# 3812   changeofscene
# 3844   changeofscene
# 3891   changeofscene
# 3948   changeofscene
# 3962   changeofscene
# 3971   changeofscene
# 4055   changeofscene
# 4071   changeofscene
# 4104   changeofscene
# 4105   changeofscene
# 4413   changeofscene
# 4436   changeofscene
# 4459   changeofscene
# 4486   changeofscene
# 4512   changeofscene
# 4513   changeofscene
# 4546   changeofscene
# 4593   changeofscene
# 4602   changeofscene
# 4613   changeofscene
# 4620   changeofscene
# 4650   changeofscene
# 4674   changeofscene
# 4678   changeofscene
# 4705   changeofscene
# 4763   changeofscene
# 4764   changeofscene
# 4801   changeofscene
# 4820   changeofscene
# 4835   changeofscene
# 4842   changeofscene
# 4843   changeofscene
# 4890   changeofscene
# 4891   changeofscene
# 4911   changeofscene
# 4935   changeofscene
# 4965   changeofscene
# 5017   changeofscene
# 5043   changeofscene
# 5074   changeofscene
# 5127   changeofscene
# 5179   changeofscene
# 5237   changeofscene
# 5255   changeofscene
# 5266   changeofscene
# 5488   changeofscene
# 6109   changeofscene
# 6323   changeofscene
# 6623   changeofscene
# 6757   changeofscene
# 7046   changeofscene
# 7465   changeofscene
# 7466   changeofscene
# 7479   changeofscene
# 7515   changeofscene
# 7543   changeofscene
# 7545   changeofscene
# 7550   changeofscene
# 7579   changeofscene
# 7584   changeofscene
# 7600   changeofscene
# 7622   changeofscene
# 7657   changeofscene
# 7667   changeofscene
# 7668   changeofscene
# 7693   changeofscene
# 7719   changeofscene
# 7741   changeofscene
# 8003   changeofscene
# 8437   changeofscene
# 8452   changeofscene
# 8474   changeofscene
# 8601   changeofscene
# 8650   changeofscene
# 8697   changeofscene
# 8767   changeofscene
# 9103   changeofscene
# 9422   changeofscene
# 9685   changeofscene
# 10098  changeofscene
# 10734  changeofscene
# 11159  changeofscene
# 11160  changeofscene
# 11202  changeofscene
# 11233  changeofscene
# 11296  changeofscene
# 11315  changeofscene
# 11335  changeofscene
# 11359  changeofscene
# 11387  changeofscene
# 11438  changeofscene
# 11466  changeofscene
# 11477  changeofscene
# 11510  changeofscene
# 11574  changeofscene
# 11597  changeofscene
# 11672  changeofscene
# 11744  changeofscene
# 12077  changeofscene
# 12085  changeofscene
# 12089  changeofscene
# 12091  changeofscene
# 12113  changeofscene
# 12219  changeofscene
# 12235  changeofscene
# 12266  changeofscene
# 12313  changeofscene
# 12331  changeofscene
# 12338  changeofscene
# 12400  changeofscene
# 12460  changeofscene
# 12472  changeofscene
# 12515  changeofscene
# 12533  changeofscene
# 12534  changeofscene
# 12548  changeofscene
# 12549  changeofscene
# 12560  changeofscene
# 12574  changeofscene
# 12599  changeofscene
# 12622  changeofscene
# 12641  changeofscene
# 12672  changeofscene
# 12693  changeofscene
# 12713  changeofscene
# 12723  changeofscene
# 12736  changeofscene
# 12751  changeofscene
# 12760  changeofscene
# 12785  changeofscene
# 12803  changeofscene
# 12835  changeofscene
# 12836  changeofscene
# 12840  changeofscene
# 12868  changeofscene
# 12897  changeofscene
# 12957  changeofscene
# 12996  changeofscene
# 13008  changeofscene
# 13041  changeofscene
# 13056  changeofscene
# 13081  changeofscene
# 13137  changeofscene
# 13204  changeofscene
# 13205  changeofscene
# 13318  changeofscene
# 13584  changeofscene
# 13604  changeofscene
# 13613  changeofscene
# 13649  changeofscene
# 13660  changeofscene
# 13685  changeofscene
# 13728  changeofscene
# 13749  changeofscene
# 13773  changeofscene
# 13775  changeofscene
# 13806  changeofscene
# 13818  changeofscene
# 13838  changeofscene
# 13859  changeofscene
# 13868  changeofscene
# 13890  changeofscene
# 13934  changeofscene
# 13969  changeofscene
# 14549  changeofscene
# 14821  changeofscene
# 14832  changeofscene
# 14853  changeofscene
# 14859  changeofscene
# 14868  changeofscene
# 14884  changeofscene
# 14888  changeofscene
# 14901  changeofscene
# 14927  changeofscene
# 14934  changeofscene
# 14990  changeofscene
# 15083  changeofscene
# 15101  changeofscene
# 15115  changeofscene
# 15119  changeofscene
# 15143  changeofscene
# 15153  changeofscene
# 15155  changeofscene
# 15166  changeofscene
# 15168  changeofscene
# 15170  changeofscene
# 15172  changeofscene
# 15225  changeofscene
# 15241  changeofscene
# 15267  changeofscene
# 15304  changeofscene
# 15323  changeofscene
# 15332  changeofscene
# 15363  changeofscene
# 15391  changeofscene
# 15401  changeofscene
# 15426  changeofscene
# 15458  changeofscene
# 15479  changeofscene
# 15507  changeofscene
# 15522  changeofscene
# 15524  changeofscene
# 15525  changeofscene
# 15535  changeofscene
# 15546  changeofscene
# 15552  changeofscene
# 15553  changeofscene
# 15568  changeofscene
# 15570  changeofscene
# 15572  changeofscene
# 15600  changeofscene
# 15611  changeofscene
# 15630  changeofscene
# 15631  changeofscene
# 15645  changeofscene
# 15670  changeofscene
# 15700  changeofscene
# 15739  changeofscene
# 15757  changeofscene
# 15767  changeofscene
# 15793  changeofscene
# 15811  changeofscene
# 15847  changeofscene
# 15883  changeofscene
# 15943  changeofscene
# 15948  changeofscene
# 15949  changeofscene
# 15952  changeofscene
# 15975  changeofscene
# 15993  changeofscene
# 16012  changeofscene
# 16013  changeofscene
# 16014  changeofscene
# 16017  changeofscene
# 16023  changeofscene
# 16029  changeofscene
# 16041  changeofscene
# 16048  changeofscene
# 16060  changeofscene
# 16074  changeofscene
# 16093  changeofscene
# 16121  changeofscene
# 16134  changeofscene
# 16166  changeofscene
# 16167  changeofscene
# 16249  changeofscene
# 16271  changeofscene
# 16282  changeofscene
# 16283  changeofscene
# 16290  changeofscene
# 16299  changeofscene
# 16300  changeofscene
# 16341  changeofscene
# 16354  changeofscene
# 16363  changeofscene
# 16379  changeofscene
# 16391  changeofscene
# 16397  changeofscene
# 16409  changeofscene
# 16458  changeofscene
# 16519  changeofscene
# 16534  changeofscene
# 16544  changeofscene
# 16550  changeofscene
# 16558  changeofscene
# 16573  changeofscene
# 16585  changeofscene
# 16595  changeofscene
# 16616  changeofscene
# 16635  changeofscene
# 16658  changeofscene
# 16665  changeofscene
# 16666  changeofscene
# 16669  changeofscene
# 16716  changeofscene
# 16726  changeofscene
# 16766  changeofscene
# 16782  changeofscene
# 16793  changeofscene
# 16794  changeofscene
# 16797  changeofscene
# 16822  changeofscene
# 16825  changeofscene
# 16852  changeofscene
# 16901  changeofscene
# 16916  changeofscene
# 16918  changeofscene
# 16925  changeofscene
# 16932  changeofscene
# 16947  changeofscene
# 16956  changeofscene
# 16961  changeofscene
# 16962  changeofscene
# 16980  changeofscene
# 16981  changeofscene
# 16983  changeofscene
# 16984  changeofscene
# 17014  changeofscene
# 17015  changeofscene
# 17047  changeofscene
# 17079  changeofscene
# 17093  changeofscene
# 17108  changeofscene
# 17130  changeofscene
# 17158  changeofscene
# 17160  changeofscene
# 17173  changeofscene
# 17186  changeofscene
# 17219  changeofscene
# 17235  changeofscene
# 17241  changeofscene
# 17248  changeofscene
# 17265  changeofscene
# 17277  changeofscene
# 17302  changeofscene
# 17305  changeofscene
# 17331  changeofscene
# 17336  changeofscene
# 17338  changeofscene
# 17390  changeofscene
# 17412  changeofscene
# 17421  changeofscene
# 17469  changeofscene
# 17482  changeofscene
# 17518  changeofscene
# 17538  changeofscene
# 17587  changeofscene
# 17622  changeofscene
# 17623  changeofscene
# 17625  changeofscene
# 17636  changeofscene
# 17638  changeofscene
# 17645  changeofscene
# 17658  changeofscene
# 17659  changeofscene
# 17676  changeofscene
# 17712  changeofscene
# 17736  changeofscene
# 17747  changeofscene
# 17755  changeofscene
# 17760  changeofscene
# 17767  changeofscene
# 17773  changeofscene
# 17790  changeofscene
# 17801  changeofscene
# 17846  changeofscene
# 17897  changeofscene
# 17898  changeofscene
# 17899  changeofscene
# 17903  changeofscene
# 17913  changeofscene
# 17917  changeofscene
# 17947  changeofscene
# 17948  changeofscene
# 17949  changeofscene
# 17950  changeofscene
# 17952  changeofscene
# 17956  changeofscene
# 17964  changeofscene
# 17970  changeofscene
# 17976  changeofscene
# 17985  changeofscene
# 17992  changeofscene
# 18012  changeofscene
# 18021  changeofscene
# 18041  changeofscene
# 18088  changeofscene
# 18099  changeofscene
# 18105  changeofscene
# 18107  changeofscene
# 18142  changeofscene
# 18148  changeofscene
# 18161  changeofscene
# 18179  changeofscene
# 18415  changeofscene
# 18416  changeofscene
# 18565  changeofscene
# 18581  changeofscene
# 18625  changeofscene
# 18649  changeofscene
# 18729  changeofscene
# 18864  changeofscene
# 18933  changeofscene
# 18964  changeofscene
# 18997  changeofscene
# 19013  changeofscene
# 19026  changeofscene
# 19174  changeofscene
# 19344  changeofscene
# 19371  changeofscene
# 19398  changeofscene
# 19429  changeofscene
# 19433  changeofscene
# 19798  changeofscene
# 20088  changeofscene
# 20378  changeofscene
# 20756  changeofscene
# 20945  changeofscene
# 21086  changeofscene
# 21284  changeofscene
# 21636  changeofscene
# 21755  changeofscene
# 21775  changeofscene
# 21949  changeofscene
# 22363  changeofscene
# 22448  changeofscene
# 22762  changeofscene
# 23280  changeofscene
# 23281  changeofscene
# 23465  changeofscene
# 23485  changeofscene
# 23490  changeofscene
# 23491  changeofscene
# 23887  changeofscene
# 24214  changeofscene
# 24666  changeofscene
# 25002  changeofscene
# 25039  changeofscene
# ...
# 18581  INT. WINTERFELL - DINING HALL
# 18625  EXT. NORTHERN WILDERNESS - DAY
# 18649  EXT. PYKE CASTLE - NIGHT
# 18729  CUT TO
# 18864  INT. RED KEEP - VAULTS
# 18933  INT. HOUSE OF BLACK AND WHITE
# 18964  EXT. NORTHERN WILDERNESS
# 18997  INT. CASTLE BLACK – JON SNOW'S CHAMBER
# 19013  INT. CASTLE BLACK - JON SNOW'S ROOM
# 19026  CUT TO
# 19174  EXT. ESSOS MOUNTAIN RANGE - DAY
# 19344  INT. WINTERFELL – ROOM
# 19371  EXT. CASTLE BLACK – COURTYARD
# 19398  INT. VAES DOTHRAK – TEMPLE OF THE DOSH KHALEEN
# 19429  INT. CASTLE BLACK - SANSA'S ROOM
# 19433  CUT TO
# 19798  CUT TO
# 20088  CUT TO
# 20378  CUT TO
# 20756  CUT TO
# 20945  CUT TO
# 21086  INT. RED KEEP - QYBURN'S LAB
# 21284  CUT TO
# 21636  CUT TO
# 21755  CUT TO - DRAGONSTONE - GREY WORM'S QUARTERS
# 21775  CUT TO - CITADEL LIBRARY
# 21949  CUT TO
# 22363  CUT TO
# 22448  CUT TO - WINTERFELL - CRYPTS
# 22762  CUT TO
# 23280  INT. DRAGONSTONE - CHAMBER OF THE PAINTED TABLE
# 23281  CUT TO
# 23465  EXT. Outside King's Landing
# 23485  CUT TO
# 23490  INT. Below deck of the Ironborn Ship
# 23491  INT. King's Landing
# 23887  CUT TO
# 24214  CUT TO
# 24666  CUT TO
# 25002  CUT TO
# 25039  CUT TO
# 25458  CUT TO

# %% [markdown]
# Finally, our process in scrapping and cleansing the dataset for `Game of Thrones` has finished. The last thing to do is export the dataframe to an external file.

# %%
script_dataframe.to_csv('Game_of_Thrones_Script_MD.csv', encoding='utf-8', index=False)

# %% [markdown]
# # Conclusion
# Scrapping web to extract the data scattered around them may take a lot of effort. We need to do bunch of manual inspect element just to get the exact position of data or information that we want to collect from all over the html parts. BeautifulSoup functionality is good, but for case like this we need to combine this package with manual inspect element to produce the desired result faster. Some of you might have different and even a better solution on extracting data from online sources, and that is a great thing. As for me, I am still learning and experimenting different methodologies to find my best practice on doing so.
#
# As for the closing, you can use this data and mine the information provided there as you please. Also, give me feedback both on this dataset and the process of getting them if you have the time.
#
# Thank you!
#
# And, Have a nice day:)
